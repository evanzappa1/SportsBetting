# %% [markdown]
# # Web Scraping UnderDog

# %%
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
import re
import json
import numpy as np
import os, sys

# %%
main_dir = os.path.normpath(os.getcwd() + os.sep + os.pardir)

# %%
driver = webdriver.Chrome(main_dir + "/UnderDog/chromedriver")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.

# %%
driver.get('https://underdogfantasy.com/pick-em/higher-lower')

# %%
content = driver.page_source
soup = BeautifulSoup(content, "html.parser")

# %%
results = soup.find_all("div", class_="styles__overUnderCell__KgzNn")
dataframe = pd.DataFrame(columns = ["player_name","prop_type","UnderDog Line"])
for a in results:
    name_line = a.find_all("div", class_="styles__overUnderCell__qdEk_")
    name = a.find("h1", class_="styles__playerName__jW6mb").text.strip()
    line = a.find("p",class_="styles__statLine__K1NYh").text.strip()
    for x in name_line:
        line = x.find("p",class_="styles__statLine__K1NYh").text.strip()
        bet_type = re.split('\d*\.?\d+',line)[1].strip()
        line = re.findall('\d*\.?\d+',line)[0]
        newRow = [name,bet_type,line]
        dataframe.loc[len(dataframe)] = newRow

dataframe['player_name'] = dataframe['player_name'].str.lower()
dataframe['prop_type'] = dataframe['prop_type'].str.lower()

# %%
#NFL Props
dataframe['prop_type'] = np.where(dataframe['prop_type']=='rushing yards', 'rush yds', 
                           np.where(dataframe['prop_type']=='rush yards', 'rush yds', 
                            np.where(dataframe['prop_type']=='passing yards', 'pass yds',
                            np.where(dataframe['prop_type']=='passing attempts', 'pass attempts',
                            np.where(dataframe['prop_type'] =='receiving yards', 'receiving yds',                 
                                            dataframe['prop_type'])))))
#MLB Props
dataframe['prop_type'] = np.where(dataframe['prop_type']=='strikeouts', 'total strikeouts', 
                                  dataframe['prop_type'])

#NHL Props
dataframe['prop_type'] = np.where(dataframe['prop_type']=='shots', 'shots on goal', 
                                  dataframe['prop_type'])

#NBA Props
dataframe['prop_type'] = np.where(dataframe['prop_type']=='pts + rebs + asts', 'pts+rebs+asts',
                                  np.where(dataframe['prop_type']=='blocks + steals', 'steals+blocks', 
                                      dataframe['prop_type']))

# %% [markdown]
# # Functions That Will Be Called

# %%
def prop_type(string):
    type_ = re.findall('(.+?)\(', string)[1].lower().strip(')')
    return type_

def player_name(string):
    name = re.findall('(.+?)\(', string)[0].lower().strip()
    return name

# %%
def get_picks(pp, pin, league):
    df = pp[pp['league']==league]
    df = df.merge(pin, how='left', on=['player_name', 'prop_type'])
    df.dropna(inplace=True)
    df.drop(columns=['prop_id', 'over_id', 'under_id', 'under_points'], inplace=True)
    df.rename(columns={'over_points':'pinnacle_line'}, inplace=True)
    
    df['favored'] = np.where(df['min_price']==df['over_price'], 'over', 'under')
    
    df['edge'] = np.where((df['pinnacle_line']<df['pp_line'])&(df['favored']=='under'), 'edge',
                         np.where((df['pinnacle_line']>df['pp_line'])&(df['favored']=='over'), 'edge',
                                 np.where(df['pinnacle_line']==df['pp_line'], 'equal',
                                         np.where((df['pinnacle_line']<df['pp_line'])&(df['favored']=='over'), 'buffer',
                                                 np.where((df['pinnacle_line']>df['pp_line'])&(df['favored']=='under'), 'buffer', 'else')))))
    df.sort_values(by='min_price', inplace=True)
    return df

def matchup_cleaning(data):
    player_props = []
    for i, d in enumerate(data['data']):
        try:
            if d['special']['category'].lower() == 'player props':
                data = {}
                data['prop_name'] = d['special']['description']
                data['prop_id'] = d['id']
                data['over_id'] = d['participants'][0]['id']
                data['under_id'] = d['participants'][1]['id']
                player_props.append(data)        
                
            
        except:
            continue
    return player_props


def straight_cleaning(data):
    prop_prices = []
    for d in data['data']:
        try:

            row = {}
            row['prop_id'] = d['matchupId']

            row['over_id'] = d['prices'][0]['participantId']
            row['over_points'] = d['prices'][0]['points']
            row['over_price'] = d['prices'][0]['price']

            row['under_id'] = d['prices'][1]['participantId']
            row['under_points'] = d['prices'][1]['points']
            row['under_price'] = d['prices'][1]['price']   

            prop_prices.append(row)

        except:
            continue
    return prop_prices

def df_manipulation(player_props,prop_prices):
    prop_df = pd.DataFrame(player_props)
    prices_df = pd.DataFrame(prop_prices)
    
    temp_df = pd.merge(prop_df, prices_df, how='left', on=['prop_id', 'over_id', 'under_id'])
    temp_df.dropna(inplace=True)
    temp_df['min_price'] = np.where(temp_df['over_price']<=temp_df['under_price'], 
                                   temp_df['over_price'], temp_df['under_price'])
    
    temp_df['player_name'] = temp_df['prop_name'].apply(player_name)
    temp_df['prop_type'] = temp_df['prop_name'].apply(prop_type)
    temp_df.drop(columns='prop_name', inplace=True)
    temp_df.drop_duplicates(inplace=True)
    
    return temp_df

# %% [markdown]
# # Pinnacle NFL Scraping

# %%
f = open(main_dir + "/Pinnacle/NFL/nfl_matchups.json")

data = json.load(f)
player_props = matchup_cleaning(data)

f.close()

# %%
f = open(main_dir + "/Pinnacle/NFL/nfl_straight.json")

data = json.load(f)
prop_prices = straight_cleaning(data)

f.close()

# %%
nfl_df = df_manipulation(player_props,prop_prices)

# %%
nfl_final = nfl_df.merge(dataframe, how='right', on=['player_name', 'prop_type'])
nfl_final.dropna(inplace = True)
nfl_final = nfl_final.sort_values(by = 'min_price', ascending = True)
nfl_final.drop(columns=['prop_id', 'over_id', 'under_id', 'under_points'], inplace=True)
nfl_final.rename(columns={'over_points':'pinnacle_line'}, inplace=True)
nfl_final['favored'] = np.where(nfl_final['min_price']==nfl_final['over_price'], 'over', 'under')
nfl_final.sort_values(by='min_price', inplace=True)

# %%
nfl_final
# Out:
#      pinnacle_line  over_price  under_price  min_price          player_name  \
# 19             2.5       129.0       -175.0     -175.0       tre'quan smith
# 35             2.5       129.0       -173.0     -173.0           a.j. green
# 53            34.5       120.0       -159.0     -159.0         daniel jones
# 73           223.5       120.0       -158.0     -158.0      taylor heinicke
# 31             4.5      -157.0        117.0     -157.0        rondale moore
# 15            25.5      -151.0        114.0     -151.0        juwan johnson
# 17            32.5       109.0       -144.0     -144.0          taysom hill
# 33             4.5      -141.0        107.0     -141.0            zach ertz
# 99            65.5      -115.0       -115.0     -115.0        dameon pierce
# 18            26.5      -115.0       -115.0     -115.0       tre'quan smith
# 37            34.5      -115.0       -115.0     -115.0       marcus mariota
# 36           193.5      -115.0       -115.0     -115.0       marcus mariota
# 62            39.5      -115.0       -115.0     -115.0            zay jones
# 80            65.5      -115.0       -115.0     -115.0    leonard fournette
# 42           285.5      -115.0       -115.0     -115.0           joe burrow
# 102          251.5      -115.0       -115.0     -115.0           derek carr
# 68            21.5      -115.0       -115.0     -115.0          aaron jones
# 105           78.5      -115.0       -115.0     -115.0        davante adams
#
#          prop_type UnderDog Line favored
# 19      receptions           2.0   under
# 35      receptions           2.0   under
# 53        rush yds          34.5   under
# 73        pass yds         225.5   under
# 31      receptions           5.0    over
# 15   receiving yds          25.5    over
# 17        rush yds          33.5   under
# 33      receptions           5.0    over
# 16      receptions           2.0   under
# 34   receiving yds          24.5   under
# 58        rush yds          14.5   under
# 83        rush yds          20.5   under
# 27        rush yds          34.5    over
# 11      receptions           4.5   under
# 90        rush yds          55.5   under
# 38   interceptions           0.5   under
# 67        rush yds          57.5   under
# 74        rush yds           9.5    over
# 28   receiving yds          64.5    over
# 23   interceptions           0.5    over
# 1    interceptions           0.5   under
# 29      receptions           5.5   under
# 26   pass attempts          35.5   under
# 20   receiving yds           5.5   under
# 78   receiving yds          51.5   under
# 0         pass yds         216.5   under
# 4    receiving yds          34.5    over
# 65   pass attempts          33.5   under
# 75   pass attempts          31.5   under
# 13      receptions           2.0   under
# 47        rush yds          12.5    over
# 84   receiving yds          16.5   under
# 87   receiving yds          27.5    over
# 72   receiving yds          32.5    over
# 77   receiving yds          19.5   under
# 82   receiving yds          30.5   under
# 14   receiving yds          29.5    over
# 91   receiving yds          40.5   under
# 46        pass yds         217.5   under
# 49   receiving yds          55.5    over
# 56        rush yds          78.5    over
# 12   receiving yds          62.5    over
# 60        rush yds          50.5    over
# 54        pass yds         195.5   under
# 69   receiving yds          10.5    over
# 100  receiving yds          61.5   under
# 71   receiving yds          47.5   under
# 61   receiving yds          51.5    over
# 70   receiving yds          54.5   under
# 86   receiving yds          65.5    over
# 85   receiving yds          67.5    over
# 101  receiving yds          41.5    over
# 57        pass yds         230.5    over
# 48        rush yds          82.5   under
# 79        pass yds         269.5   under
# 98        pass yds         230.5   under
# 32   receiving yds          48.5    over
# 2         rush yds          64.5    over
# 30   receiving yds          47.5    over
# 99        rush yds          69.5    over
# 18   receiving yds          26.5    over
# 37        rush yds          34.5    over
# 36        pass yds         193.5    over
# 62   receiving yds          40.5    over
# 80        rush yds          65.5    over
# 42        pass yds         285.5    over
# 102       pass yds         260.5    over
# 68   receiving yds          21.5    over
# 105  receiving yds          82.5    over

# %% [markdown]
# # Pinnacle MLB Scraping

# %%
f = open(main_dir + "/Pinnacle/MLB/mlb_matchups.json")
  
data = json.load(f)
player_props = matchup_cleaning(data)

f.close()

# %%
f = open(main_dir + "/Pinnacle/MLB/mlb_straight.json")
  
data = json.load(f)
prop_prices = straight_cleaning(data)

f.close()

# %%
mlb_df = df_manipulation(player_props, prop_prices)

# %%
mlb_final = mlb_df.merge(dataframe, how='right', on=['player_name', 'prop_type'])
mlb_final.dropna(inplace = True)
mlb_final = mlb_final.sort_values(by = 'min_price', ascending = True)
mlb_final.drop(columns=['prop_id', 'over_id', 'under_id', 'under_points'], inplace=True)
mlb_final.rename(columns={'over_points':'pinnacle_line'}, inplace=True)
mlb_final['favored'] = np.where(mlb_final['min_price']==mlb_final['over_price'], 'over', 'under')
mlb_final.sort_values(by='min_price', inplace=True)

# %%
mlb_final
# Out:
# Empty DataFrame
# Columns: [pinnacle_line, over_price, under_price, min_price, player_name, prop_type, UnderDog Line, favored]
# Index: []

# %% [markdown]
# # Pinnacle NHL Scraping

# %%
f = open(main_dir + "/Pinnacle/NHL/nhl_matchups.json")
  
data = json.load(f)
player_props = matchup_cleaning(data)

f.close()

# %%
f = open(main_dir + "/Pinnacle/NHL/nhl_straight.json")
  
data = json.load(f)
prop_prices = straight_cleaning(data)

f.close()

# %%
nhl_df = df_manipulation(player_props, prop_prices)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/9s/f_wwnnxn1x54pvjy5pjkrmxh0000gn/T/ipykernel_9166/1519307031.py in <module>
# ----> 1 nhl_df = df_manipulation(player_props, prop_prices)
#
# /var/folders/9s/f_wwnnxn1x54pvjy5pjkrmxh0000gn/T/ipykernel_9166/4121825375.py in df_manipulation(player_props, prop_prices)
#      60     prices_df = pd.DataFrame(prop_prices)
#      61
# ---> 62     temp_df = pd.merge(prop_df, prices_df, how='left', on=['prop_id', 'over_id', 'under_id'])
#      63     temp_df.dropna(inplace=True)
#      64     temp_df['min_price'] = np.where(temp_df['over_price']<=temp_df['under_price'],
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     117         copy=copy,
#     118         indicator=indicator,
# --> 119         validate=validate,
#     120     )
#     121     return op.get_result()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
#     701         # validate the merge keys dtypes. We may need to coerce
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1107                         right_keys.append(rk)
#    1108                     if lk is not None:
# -> 1109                         left_keys.append(left._get_label_or_level_values(lk))
#    1110                         join_names.append(lk)
#    1111                     else:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'prop_id'

# %%
nhl_final = nhl_df.merge(dataframe, how='right', on=['player_name', 'prop_type'])
nhl_final.dropna(inplace = True)
nhl_final = nhl_final.sort_values(by = 'min_price', ascending = True)
nhl_final.drop(columns=['prop_id', 'over_id', 'under_id', 'under_points'], inplace=True)
nhl_final.rename(columns={'over_points':'pinnacle_line'}, inplace=True)
nhl_final['favored'] = np.where(nhl_final['min_price']==nhl_final['over_price'], 'over', 'under')
nhl_final.sort_values(by='min_price', inplace=True)
nhl_final
# Out:
# Empty DataFrame
# Columns: [pinnacle_line, over_price, under_price, min_price, player_name, prop_type, UnderDog Line, favored]
# Index: []

# %% [markdown]
# # Pinnacle NBA Scraping

# %%
# Opening JSON file
f = open(main_dir + "/Pinnacle/NBA/nba_matchups.json")

data = json.load(f)
player_props = matchup_cleaning(data)

f.close()

# %%
f = open(main_dir + "/Pinnacle/NBA/nba_straight.json")
  
data = json.load(f)
prop_prices = straight_cleaning(data)

f.close()

# %%
nba_df = df_manipulation(player_props, prop_prices)
nba_df['prop_type'].unique()
# Out:
# array(['steals+blocks', 'double+double', 'turnovers', 'blocks', 'assists',
#        'points', '3 point fg', 'pts+rebs+asts', 'rebounds'], dtype=object)

# %%
nba_final = nba_df.merge(dataframe, how = 'right', on = ['player_name','prop_type'])
nba_final.dropna(inplace = True)
nba_final.drop(columns=['prop_id', 'over_id', 'under_id', 'under_points'], inplace=True)
nba_final.rename(columns={'over_points':'pinnacle_line'}, inplace=True)
nba_final['favored'] = np.where(nba_final['min_price']==nba_final['over_price'], 'over', 'under')
nba_final = nba_final.sort_values(by='min_price', ascending=True)
nba_final
# Out:
#      pinnacle_line  over_price  under_price  min_price            player_name  \
# 146            6.5       118.0       -159.0     -159.0           james harden
# 182            5.5      -157.0        117.0     -157.0           lebron james
# 133            4.5      -145.0        109.0     -145.0            brook lopez
# 165            7.5       107.0       -142.0     -142.0            paul george
# 164            4.5       104.0       -138.0     -138.0            paul george
# 142           11.5       103.0       -136.0     -136.0            joel embiid
# 145            9.5       103.0       -136.0     -136.0           james harden
# 191            9.5       102.0       -135.0     -135.0          anthony davis
# 183            8.5      -132.0       -101.0     -132.0           lebron james
# 188            1.5      -130.0       -102.0     -130.0          anthony davis
# 129           19.5      -103.0       -129.0     -129.0           jrue holiday
# 162           11.5      -129.0       -103.0     -129.0            p.j. tucker
# 180           29.5      -103.0       -128.0     -128.0           lebron james
# 135           17.5      -104.0       -128.0     -128.0            brook lopez
# 175            8.5      -127.0       -105.0     -127.0            ivica zubac
# 184           44.5      -105.0       -126.0     -126.0           lebron james
# 118           30.5      -126.0       -105.0     -126.0  giannis antetokounmpo
# 121           11.5      -126.0       -105.0     -126.0  giannis antetokounmpo
# 124            4.5      -126.0       -105.0     -126.0           jrue holiday
# 152           23.5      -106.0       -125.0     -125.0          tobias harris
# 136           26.5      -108.0       -123.0     -123.0            joel embiid
# 141           41.5      -108.0       -123.0     -123.0            joel embiid
# 158            5.5      -123.0       -107.0     -123.0            p.j. tucker
# 167           34.5      -108.0       -123.0     -123.0            paul george
# 143           38.5      -108.0       -122.0     -122.0           james harden
# 138            3.5      -110.0       -121.0     -121.0            joel embiid
# 126            6.5      -121.0       -110.0     -121.0           jrue holiday
# 172            8.5      -120.0       -110.0     -120.0            ivica zubac
# 119           48.5      -119.0       -111.0     -119.0  giannis antetokounmpo
# 190           36.5      -111.0       -119.0     -119.0          anthony davis
# 147           18.5      -118.0       -112.0     -118.0           tyrese maxey
# 154            5.5      -118.0       -113.0     -118.0          tobias harris
# 148           24.5      -117.0       -113.0     -117.0           tyrese maxey
# 161            4.5      -117.0       -113.0     -117.0            p.j. tucker
# 173           18.5      -117.0       -113.0     -117.0            ivica zubac
# 144           22.5      -116.0       -114.0     -116.0           james harden
# 185           24.5      -114.0       -116.0     -116.0          anthony davis
# 153           14.5      -116.0       -114.0     -116.0          tobias harris
# 128           30.5      -116.0       -114.0     -116.0           jrue holiday
# 177            1.5      -114.0       -116.0     -116.0           lebron james
# 134           11.5      -115.0       -115.0     -115.0            brook lopez
#
#          prop_type UnderDog Line favored
# 146       rebounds           6.0   under
# 182        assists           6.0    over
# 133       rebounds           4.5    over
# 165       rebounds           7.5   under
# 164        assists           4.5   under
# 142       rebounds          11.5   under
# 145        assists           9.5   under
# 191       rebounds           9.5   under
# 183       rebounds           8.5    over
# 188         blocks           1.5    over
# 129         points          19.5   under
# 162  pts+rebs+asts          11.5    over
# 180         points          29.5   under
# 135  pts+rebs+asts          17.5   under
# 175         points           8.5    over
# 184  pts+rebs+asts          44.5   under
# 118         points          30.5    over
# 121       rebounds          11.5    over
# 124       rebounds           4.5    over
# 152  pts+rebs+asts          23.5   under
# 136         points          26.5   under
# 141  pts+rebs+asts          41.5   under
# 158         points           5.5    over
# 167  pts+rebs+asts          34.5   under
# 143  pts+rebs+asts          38.5   under
# 138        assists           3.5   under
# 126        assists           6.5    over
# 172       rebounds           8.5    over
# 119  pts+rebs+asts          48.5    over
# 190  pts+rebs+asts          36.5   under
# 147         points          18.5    over
# 154       rebounds           5.5    over
# 148  pts+rebs+asts          24.5    over
# 161       rebounds           4.5    over
# 173  pts+rebs+asts          18.5    over
# 144         points          22.5    over
# 185         points          24.5   under
# 153         points          14.5    over
# 128  pts+rebs+asts          30.5    over
# 177  steals+blocks           1.5   under
# 134         points          11.5    over

# %% [markdown]
# # All Sports Dataframe

# %%
full_df = nhl_final.append(nfl_final).append(mlb_final).append(nba_final)
pd.set_option('display.max_rows',None)
full_df.sort_values(by = 'min_price', ascending = True)
# Out:
#      pinnacle_line  over_price  under_price  min_price            player_name  \
# 19             2.5       129.0       -175.0     -175.0         tre'quan smith
# 35             2.5       129.0       -173.0     -173.0             a.j. green
# 146            6.5       118.0       -159.0     -159.0           james harden
# 53            34.5       120.0       -159.0     -159.0           daniel jones
# 73           223.5       120.0       -158.0     -158.0        taylor heinicke
# 31             4.5      -157.0        117.0     -157.0          rondale moore
# 182            5.5      -157.0        117.0     -157.0           lebron james
# 15            25.5      -151.0        114.0     -151.0          juwan johnson
# 133            4.5      -145.0        109.0     -145.0            brook lopez
# 17            32.5       109.0       -144.0     -144.0            taysom hill
# 165            7.5       107.0       -142.0     -142.0            paul george
# 33             4.5      -141.0        107.0     -141.0              zach ertz
# 16             2.5       105.0       -140.0     -140.0          juwan johnson
# 58            13.5       105.0       -139.0     -139.0        trevor lawrence
# 34            24.5       105.0       -139.0     -139.0             a.j. green
# 83            20.5       104.0       -138.0     -138.0          rachaad white
# 164            4.5       104.0       -138.0     -138.0            paul george
# 145            9.5       103.0       -136.0     -136.0           james harden
# 142           11.5       103.0       -136.0     -136.0            joel embiid
# 191            9.5       102.0       -135.0     -135.0          anthony davis
# 27            33.5      -135.0        102.0     -135.0           kyler murray
# 11             4.5       100.0       -133.0     -133.0            chris olave
# 183            8.5      -132.0       -101.0     -132.0           lebron james
# 90            55.5      -100.0       -132.0     -132.0    christian mccaffrey
# 38             0.5      -100.0       -132.0     -132.0         marcus mariota
# 28            61.5      -131.0       -101.0     -131.0        deandre hopkins
# 74            10.5      -131.0       -101.0     -131.0        taylor heinicke
# 118         points          30.5    over
# 121       rebounds          11.5    over
# 20   receiving yds           5.5   under
# 78   receiving yds          51.5   under
# 152  pts+rebs+asts          23.5   under
# 0         pass yds         216.5   under
# 4    receiving yds          34.5    over
# 65   pass attempts          33.5   under
# 158         points           5.5    over
# 167  pts+rebs+asts          34.5   under
# 136         points          26.5   under
# 141  pts+rebs+asts          41.5   under
# 13      receptions           2.0   under
# 75   pass attempts          31.5   under
# 47        rush yds          12.5    over
# 143  pts+rebs+asts          38.5   under
# 126        assists           6.5    over
# 138        assists           3.5   under
# 84   receiving yds          16.5   under
# 87   receiving yds          27.5    over
# 172       rebounds           8.5    over
# 82   receiving yds          30.5   under
# 77   receiving yds          19.5   under
# 190  pts+rebs+asts          36.5   under
# 119  pts+rebs+asts          48.5    over
# 72   receiving yds          32.5    over
# 154       rebounds           5.5    over
# 14   receiving yds          29.5    over
# 147         points          18.5    over
# 91   receiving yds          40.5   under
# 60        rush yds          50.5    over
# 49   receiving yds          55.5    over
# 12   receiving yds          62.5    over
# 148  pts+rebs+asts          24.5    over
# 161       rebounds           4.5    over
# 173  pts+rebs+asts          18.5    over
# 61   receiving yds          51.5    over
# 71   receiving yds          47.5   under
# 100  receiving yds          61.5   under
# 69   receiving yds          10.5    over
# 56        rush yds          78.5    over
# 46        pass yds         217.5   under
# 54        pass yds         195.5   under
# 144         points          22.5    over
# 185         points          24.5   under
# 153         points          14.5    over
# 128  pts+rebs+asts          30.5    over
# 79        pass yds         269.5   under
# 2         rush yds          64.5    over
# 70   receiving yds          54.5   under
# 86   receiving yds          65.5    over
# 85   receiving yds          67.5    over
# 101  receiving yds          41.5    over
# 57        pass yds         230.5    over
# 48        rush yds          82.5   under
# 177  steals+blocks           1.5   under
# 98        pass yds         230.5   under
# 32   receiving yds          48.5    over
# 68   receiving yds          21.5    over
# 30   receiving yds          47.5    over
# 99        rush yds          69.5    over
# 18   receiving yds          26.5    over
# 37        rush yds          34.5    over
# 36        pass yds         193.5    over
# 62   receiving yds          40.5    over
# 80        rush yds          65.5    over
# 42        pass yds         285.5    over
# 102       pass yds         260.5    over
# 105  receiving yds          82.5    over
# 134         points          11.5    over

# %% [markdown]
# # Creating Buffers

# %%
full_df['UnderDog Line'] = full_df['UnderDog Line'].astype(float)
conditions = [
    full_df['UnderDog Line'] == full_df['pinnacle_line'],
    ((full_df['UnderDog Line'] > full_df['pinnacle_line'])
         & (full_df['favored'] == 'under')),
    ((full_df['UnderDog Line'] < full_df['pinnacle_line'])
         & (full_df['favored'] == 'over')),
    full_df['UnderDog Line'] != full_df['pinnacle_line']
]
values = [
    'equal','edge', 'edge', 'buffer'
]
full_df['edge'] = np.select(conditions, values)
full_df
# Out:
#      pinnacle_line  over_price  under_price  min_price            player_name  \
# 19             2.5       129.0       -175.0     -175.0         tre'quan smith
# 35             2.5       129.0       -173.0     -173.0             a.j. green
# 53            34.5       120.0       -159.0     -159.0           daniel jones
# 177            1.5      -114.0       -116.0     -116.0           lebron james
# 134           11.5      -115.0       -115.0     -115.0            brook lopez
#
#          prop_type  UnderDog Line favored    edge
# 19      receptions            2.0   under  buffer
# 35      receptions            2.0   under  buffer
# 53        rush yds           34.5   under   equal
# 73        pass yds          225.5   under    edge
# 31      receptions            5.0    over  buffer
# 15   receiving yds           25.5    over   equal
# 17        rush yds           33.5   under    edge
# 33      receptions            5.0    over  buffer
# 16      receptions            2.0   under  buffer
# 34   receiving yds           24.5   under   equal
# 58        rush yds           14.5   under    edge
# 83        rush yds           20.5   under   equal
# 27        rush yds           34.5    over  buffer
# 11      receptions            4.5   under   equal
# 90        rush yds           55.5   under   equal
# 38   interceptions            0.5   under   equal
# 67        rush yds           57.5   under    edge
# 74        rush yds            9.5    over    edge
# 28   receiving yds           64.5    over  buffer
# 23   interceptions            0.5    over   equal
# 1    interceptions            0.5   under   equal
# 29      receptions            5.5   under   equal
# 26   pass attempts           35.5   under   equal
# 20   receiving yds            5.5   under    edge
# 78   receiving yds           51.5   under    edge
# 0         pass yds          216.5   under   equal
# 4    receiving yds           34.5    over  buffer
# 65   pass attempts           33.5   under   equal
# 75   pass attempts           31.5   under  buffer
# 13      receptions            2.0   under  buffer
# 47        rush yds           12.5    over  buffer
# 84   receiving yds           16.5   under   equal
# 87   receiving yds           27.5    over   equal
# 72   receiving yds           32.5    over   equal
# 77   receiving yds           19.5   under   equal
# 82   receiving yds           30.5   under   equal
# 14   receiving yds           29.5    over  buffer
# 91   receiving yds           40.5   under    edge
# 46        pass yds          217.5   under    edge
# 49   receiving yds           55.5    over  buffer
# 56        rush yds           78.5    over  buffer
# 12   receiving yds           62.5    over  buffer
# 60        rush yds           50.5    over  buffer
# 54        pass yds          195.5   under    edge
# 69   receiving yds           10.5    over   equal
# 100  receiving yds           61.5   under  buffer
# 71   receiving yds           47.5   under    edge
# 61   receiving yds           51.5    over  buffer
# 70   receiving yds           54.5   under    edge
# 86   receiving yds           65.5    over  buffer
# 85   receiving yds           67.5    over  buffer
# 101  receiving yds           41.5    over  buffer
# 57        pass yds          230.5    over  buffer
# 48        rush yds           82.5   under    edge
# 79        pass yds          269.5   under    edge
# 98        pass yds          230.5   under   equal
# 32   receiving yds           48.5    over  buffer
# 2         rush yds           64.5    over  buffer
# 30   receiving yds           47.5    over  buffer
# 99        rush yds           69.5    over  buffer
# 18   receiving yds           26.5    over   equal
# 37        rush yds           34.5    over   equal
# 36        pass yds          193.5    over   equal
# 62   receiving yds           40.5    over  buffer
# 80        rush yds           65.5    over   equal
# 42        pass yds          285.5    over   equal
# 102       pass yds          260.5    over  buffer
# 68   receiving yds           21.5    over   equal
# 105  receiving yds           82.5    over  buffer
# 146       rebounds            6.0   under  buffer
# 182        assists            6.0    over  buffer
# 133       rebounds            4.5    over   equal
# 165       rebounds            7.5   under   equal
# 164        assists            4.5   under   equal
# 142       rebounds           11.5   under   equal
# 145        assists            9.5   under   equal
# 191       rebounds            9.5   under   equal
# 183       rebounds            8.5    over   equal
# 188         blocks            1.5    over   equal
# 129         points           19.5   under   equal
# 162  pts+rebs+asts           11.5    over   equal
# 180         points           29.5   under   equal
# 135  pts+rebs+asts           17.5   under   equal
# 175         points            8.5    over   equal
# 184  pts+rebs+asts           44.5   under   equal
# 118         points           30.5    over   equal
# 121       rebounds           11.5    over   equal
# 124       rebounds            4.5    over   equal
# 152  pts+rebs+asts           23.5   under   equal
# 136         points           26.5   under   equal
# 141  pts+rebs+asts           41.5   under   equal
# 158         points            5.5    over   equal
# 167  pts+rebs+asts           34.5   under   equal
# 143  pts+rebs+asts           38.5   under   equal
# 138        assists            3.5   under   equal
# 126        assists            6.5    over   equal
# 172       rebounds            8.5    over   equal
# 119  pts+rebs+asts           48.5    over   equal
# 190  pts+rebs+asts           36.5   under   equal
# 147         points           18.5    over   equal
# 154       rebounds            5.5    over   equal
# 148  pts+rebs+asts           24.5    over   equal
# 161       rebounds            4.5    over   equal
# 173  pts+rebs+asts           18.5    over   equal
# 144         points           22.5    over   equal
# 185         points           24.5   under   equal
# 153         points           14.5    over   equal
# 128  pts+rebs+asts           30.5    over   equal
# 177  steals+blocks            1.5   under   equal
# 134         points           11.5    over   equal

# %% [markdown]
# # Dropping Buffers

# %%
no_buffer_df = full_df[full_df['edge']!= 'buffer']
no_buffer_df
# Out:
#      pinnacle_line  over_price  under_price  min_price            player_name  \
# 53            34.5       120.0       -159.0     -159.0           daniel jones
# 73           223.5       120.0       -158.0     -158.0        taylor heinicke
# 15            25.5      -151.0        114.0     -151.0          juwan johnson
# 17            32.5       109.0       -144.0     -144.0            taysom hill
# 34            24.5       105.0       -139.0     -139.0             a.j. green
# 58            13.5       105.0       -139.0     -139.0        trevor lawrence
# 83            20.5       104.0       -138.0     -138.0          rachaad white
# 11             4.5       100.0       -133.0     -133.0            chris olave
# 90            55.5      -100.0       -132.0     -132.0    christian mccaffrey
# 38             0.5      -100.0       -132.0     -132.0         marcus mariota
# 67            54.5      -101.0       -131.0     -131.0            aaron jones
# 74            10.5      -131.0       -101.0     -131.0        taylor heinicke
# 23             0.5      -129.0       -102.0     -129.0           kyler murray
# 1              0.5      -104.0       -128.0     -128.0            andy dalton
# 29             5.5      -104.0       -128.0     -128.0        deandre hopkins
# 26            35.5      -104.0       -127.0     -127.0           kyler murray
# 20             4.5      -105.0       -126.0     -126.0         keith kirkwood
# 78            50.5      -105.0       -125.0     -125.0         terry mclaurin
# 0            216.5      -106.0       -124.0     -124.0            andy dalton
# 65            33.5      -107.0       -124.0     -124.0          aaron rodgers
# 84            16.5      -109.0       -121.0     -121.0          rachaad white
# 87            27.5      -120.0       -110.0     -120.0             cade otton
# 72            32.5      -119.0       -112.0     -119.0          robert tonyan
# 77            19.5      -111.0       -119.0     -119.0          j.d. mckissic
# 82            30.5      -111.0       -119.0     -119.0      leonard fournette
# 91            39.5      -112.0       -118.0     -118.0    christian mccaffrey
# 134           11.5      -115.0       -115.0     -115.0            brook lopez
#
#          prop_type  UnderDog Line favored   edge
# 53        rush yds           34.5   under  equal
# 73        pass yds          225.5   under   edge
# 15   receiving yds           25.5    over  equal
# 17        rush yds           33.5   under   edge
# 34   receiving yds           24.5   under  equal
# 58        rush yds           14.5   under   edge
# 83        rush yds           20.5   under  equal
# 11      receptions            4.5   under  equal
# 90        rush yds           55.5   under  equal
# 38   interceptions            0.5   under  equal
# 67        rush yds           57.5   under   edge
# 74        rush yds            9.5    over   edge
# 23   interceptions            0.5    over  equal
# 1    interceptions            0.5   under  equal
# 29      receptions            5.5   under  equal
# 26   pass attempts           35.5   under  equal
# 20   receiving yds            5.5   under   edge
# 78   receiving yds           51.5   under   edge
# 0         pass yds          216.5   under  equal
# 65   pass attempts           33.5   under  equal
# 84   receiving yds           16.5   under  equal
# 87   receiving yds           27.5    over  equal
# 72   receiving yds           32.5    over  equal
# 77   receiving yds           19.5   under  equal
# 82   receiving yds           30.5   under  equal
# 91   receiving yds           40.5   under   edge
# 46        pass yds          217.5   under   edge
# 54        pass yds          195.5   under   edge
# 69   receiving yds           10.5    over  equal
# 71   receiving yds           47.5   under   edge
# 70   receiving yds           54.5   under   edge
# 48        rush yds           82.5   under   edge
# 79        pass yds          269.5   under   edge
# 98        pass yds          230.5   under  equal
# 18   receiving yds           26.5    over  equal
# 37        rush yds           34.5    over  equal
# 36        pass yds          193.5    over  equal
# 80        rush yds           65.5    over  equal
# 42        pass yds          285.5    over  equal
# 68   receiving yds           21.5    over  equal
# 133       rebounds            4.5    over  equal
# 165       rebounds            7.5   under  equal
# 164        assists            4.5   under  equal
# 142       rebounds           11.5   under  equal
# 145        assists            9.5   under  equal
# 191       rebounds            9.5   under  equal
# 183       rebounds            8.5    over  equal
# 188         blocks            1.5    over  equal
# 129         points           19.5   under  equal
# 162  pts+rebs+asts           11.5    over  equal
# 180         points           29.5   under  equal
# 135  pts+rebs+asts           17.5   under  equal
# 175         points            8.5    over  equal
# 184  pts+rebs+asts           44.5   under  equal
# 118         points           30.5    over  equal
# 121       rebounds           11.5    over  equal
# 124       rebounds            4.5    over  equal
# 152  pts+rebs+asts           23.5   under  equal
# 136         points           26.5   under  equal
# 141  pts+rebs+asts           41.5   under  equal
# 158         points            5.5    over  equal
# 167  pts+rebs+asts           34.5   under  equal
# 143  pts+rebs+asts           38.5   under  equal
# 138        assists            3.5   under  equal
# 126        assists            6.5    over  equal
# 172       rebounds            8.5    over  equal
# 119  pts+rebs+asts           48.5    over  equal
# 190  pts+rebs+asts           36.5   under  equal
# 147         points           18.5    over  equal
# 154       rebounds            5.5    over  equal
# 148  pts+rebs+asts           24.5    over  equal
# 161       rebounds            4.5    over  equal
# 173  pts+rebs+asts           18.5    over  equal
# 144         points           22.5    over  equal
# 185         points           24.5   under  equal
# 153         points           14.5    over  equal
# 128  pts+rebs+asts           30.5    over  equal
# 177  steals+blocks            1.5   under  equal
# 134         points           11.5    over  equal
