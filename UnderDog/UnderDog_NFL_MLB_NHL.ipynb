# %% [markdown]
# # Web Scraping UnderDog

# %%
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
import re
import json
import numpy as np
import os, sys

# %%
main_dir = os.path.normpath(os.getcwd() + os.sep + os.pardir)

# %%
driver = webdriver.Chrome(main_dir + "/UnderDog/chromedriver")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.

# %%
driver.get('https://underdogfantasy.com/pick-em/higher-lower')

# %%
content = driver.page_source
soup = BeautifulSoup(content, "html.parser")

# %%
results = soup.find_all("div", class_="styles__overUnderCell__KgzNn")
dataframe = pd.DataFrame(columns = ["player_name","prop_type","UnderDog Line"])
for a in results:
    name_line = a.find_all("div", class_="styles__overUnderCell__qdEk_")
    name = a.find("h1", class_="styles__playerName__jW6mb").text.strip()
    line = a.find("p",class_="styles__statLine__K1NYh").text.strip()
    for x in name_line:
        line = x.find("p",class_="styles__statLine__K1NYh").text.strip()
        bet_type = re.split('\d*\.?\d+',line)[1].strip()
        line = re.findall('\d*\.?\d+',line)[0]
        newRow = [name,bet_type,line]
        dataframe.loc[len(dataframe)] = newRow

dataframe['player_name'] = dataframe['player_name'].str.lower()
dataframe['prop_type'] = dataframe['prop_type'].str.lower()

# %%
#NFL Props
dataframe['prop_type'] = np.where(dataframe['prop_type']=='rushing yards', 'rush yds', 
                           np.where(dataframe['prop_type']=='rush yards', 'rush yds', 
                            np.where(dataframe['prop_type']=='passing yards', 'pass yds',
                            np.where(dataframe['prop_type']=='passing attempts', 'pass attempts',
                            np.where(dataframe['prop_type'] =='receiving yards', 'receiving yds',                 
                                            dataframe['prop_type'])))))
#MLB Props
dataframe['prop_type'] = np.where(dataframe['prop_type']=='strikeouts', 'total strikeouts', 
                                  dataframe['prop_type'])

#NHL Props
dataframe['prop_type'] = np.where(dataframe['prop_type']=='shots', 'shots on goal', 
                                  dataframe['prop_type'])

# %% [markdown]
# # Functions That Will Be Called

# %%
def prop_type(string):
    type_ = re.findall('(.+?)\(', string)[1].lower().strip(')')
    return type_

def player_name(string):
    name = re.findall('(.+?)\(', string)[0].lower().strip()
    return name

# %%
def get_picks(pp, pin, league):
    df = pp[pp['league']==league]
    df = df.merge(pin, how='left', on=['player_name', 'prop_type'])
    df.dropna(inplace=True)
    df.drop(columns=['prop_id', 'over_id', 'under_id', 'under_points'], inplace=True)
    df.rename(columns={'over_points':'pinnacle_line'}, inplace=True)
    
    df['favored'] = np.where(df['min_price']==df['over_price'], 'over', 'under')
    
    df['edge'] = np.where((df['pinnacle_line']<df['pp_line'])&(df['favored']=='under'), 'edge',
                         np.where((df['pinnacle_line']>df['pp_line'])&(df['favored']=='over'), 'edge',
                                 np.where(df['pinnacle_line']==df['pp_line'], 'equal',
                                         np.where((df['pinnacle_line']<df['pp_line'])&(df['favored']=='over'), 'buffer',
                                                 np.where((df['pinnacle_line']>df['pp_line'])&(df['favored']=='under'), 'buffer', 'else')))))
    df.sort_values(by='min_price', inplace=True)
    return df

# %% [markdown]
# # Pinnacle NFL Scraping

# %%
# Opening JSON file
f = open(main_dir + "/Pinnacle/NFL/nfl_matchups.json")
  
# returns JSON object as 
# a dictionary
data = json.load(f)
  
# Iterating through the json
# list
player_props = []
#test = []
for i, d in enumerate(data['data']):
    try:
        if d['special']['category'].lower() == 'player props':
            data = {}
            data['prop_name'] = d['special']['description']
            data['prop_id'] = d['id']
            data['over_id'] = d['participants'][0]['id']
            data['under_id'] = d['participants'][1]['id']
            player_props.append(data)        
                
            
    except:
        continue

# Closing file
f.close()
#print(count)

# %%
# Opening JSON file
f = open(main_dir + "/Pinnacle/NFL/nfl_straight.json")
  
# returns JSON object as 
# a dictionary
data = json.load(f)
prop_prices = []
for d in data['data']:
    try:

        row = {}
        row['prop_id'] = d['matchupId']
    
        row['over_id'] = d['prices'][0]['participantId']
        row['over_points'] = d['prices'][0]['points']
        row['over_price'] = d['prices'][0]['price']
    
        row['under_id'] = d['prices'][1]['participantId']
        row['under_points'] = d['prices'][1]['points']
        row['under_price'] = d['prices'][1]['price']   
 
        prop_prices.append(row)
    
    except:
        continue


    
# Closing file
f.close()
#print(count)

# %%
nfl_propd = pd.DataFrame(player_props)
nfl_prices = pd.DataFrame(prop_prices)

# %%
nfl_df = pd.merge(nfl_propd, nfl_prices, how='left', on=['prop_id', 'over_id', 'under_id'])
nfl_df.dropna(inplace=True)
nfl_df['min_price'] = np.where(nfl_df['over_price']<=nfl_df['under_price'], 
                               nfl_df['over_price'], nfl_df['under_price'])
nfl_df
# Out:
#                                        prop_name     prop_id     over_id  \
# 0      Rondale Moore (Long Reception)(must play)  1561603507  1561603508
# 4           Zach Ertz (TD Receptions)(must play)  1561528424  1561528425
# 5      Tre'Quan Smith (Receiving Yds)(must play)  1561603385  1561603386
# 6         Chris Olave (Receiving Yds)(must play)  1561603367  1561603368
# 7   Marquez Callaway (Long Reception)(must play)  1561603400  1561603401
# 8              Kyler Murray (Rush TD)(must play)  1561603448  1561603449
# 9     Tre'Quan Smith (Long Reception)(must play)  1561603388  1561603389
# 10    DeAndre Hopkins (TD Receptions)(must play)  1561603442  1561603443
# 11            Kyler Murray (Rush Yds)(must play)  1561603445  1561603446
# 12     Keith Kirkwood (Receiving Yds)(must play)  1561603408  1561603409
# 13     Tre'Quan Smith (TD Receptions)(must play)  1561511872  1561511873
# 14      Juwan Johnson (TD Receptions)(must play)  1561511884  1561511885
# 15          Zach Ertz (Receiving Yds)(must play)  1561528421  1561528422
# 16      Juwan Johnson (Receiving Yds)(must play)  1561603364  1561603365
# 17        Chris Olave (TD Receptions)(must play)  1561511890  1561511891
# 18       Chris Olave (Long Reception)(must play)  1561603370  1561603371
# 19              Taysom Hill (Rush TD)(must play)  1561579441  1561579442
# 20   Marquez Callaway (Receiving Yds)(must play)  1561603397  1561603398
# 21       Kyler Murray (Interceptions)(must play)  1561511881  1561511882
# 22            Alvin Kamara (Rush Yds)(must play)  1561511866  1561511867
# 24         Zach Ertz (Long Reception)(must play)  1561603513  1561603514
# 25             Taysom Hill (Rush Yds)(must play)  1561603451  1561603452
# 26             Alvin Kamara (Rush TD)(must play)  1561511869  1561511870
# 27   DeAndre Hopkins (Long Reception)(must play)  1561603510  1561603511
# 28    DeAndre Hopkins (Receiving Yds)(must play)  1561603439  1561603440
# 29   Marquez Callaway (TD Receptions)(must play)  1561511887  1561511888
# 30          Mark Ingram II (Rush Yds)(must play)  1561511845  1561511846
# 31      Marquez Callaway (Receptions)(must play)  1561603394  1561603395
# 32      Rondale Moore (Receiving Yds)(must play)  1561603455  1561603456
# 33      Alvin Kamara (Long Reception)(must play)  1561511863  1561511864
# 34     Juwan Johnson (Long Reception)(must play)  1561603361  1561603362
# 36       Alvin Kamara (Receiving Yds)(must play)  1561511854  1561511855
# 37        Tre'Quan Smith (Receptions)(must play)  1561603391  1561603392
# 39     Kyler Murray (Long Completion)(must play)  1561528395  1561528396
#
#       under_id  over_points  over_price  under_points  under_price  min_price
# 0   1561603509         19.5      -108.0          19.5       -122.0     -122.0
# 4   1561528426          0.5       226.0           0.5       -352.0     -352.0
# 5   1561603387         27.5      -112.0          27.5       -118.0     -118.0
# 6   1561603369         60.5      -113.0          60.5       -117.0     -117.0
# 7   1561603402         16.5      -119.0          16.5       -111.0     -119.0
# 8   1561603450          0.5       239.0           0.5       -392.0     -392.0
# 9   1561603390         16.5      -107.0          16.5       -124.0     -124.0
# 10  1561603444          0.5       165.0           0.5       -236.0     -236.0
# 11  1561603447         29.5      -125.0          29.5       -106.0     -125.0
# 12  1561603410          5.5      -118.0           5.5       -112.0     -118.0
# 13  1561511874          0.5       394.0           0.5       -832.0     -832.0
# 14  1561511886          0.5       427.0           0.5       -960.0     -960.0
# 15  1561528423         47.5      -118.0          47.5       -112.0     -118.0
# 16  1561603366         22.5      -115.0          22.5       -115.0     -115.0
# 17  1561511892          0.5       195.0           0.5       -289.0     -289.0
# 18  1561603372         23.5      -109.0          23.5       -121.0     -121.0
# 19  1561579443          0.5       148.0           0.5       -205.0     -205.0
# 20  1561603399         29.5      -114.0          29.5       -116.0     -116.0
# 21  1561511883          0.5      -126.0           0.5       -105.0     -126.0
# 22  1561511868         60.5      -112.0          60.5       -119.0     -119.0
# 24  1561603515         18.5      -106.0          18.5       -125.0     -125.0
# 25  1561603453         30.5      -114.0          30.5       -116.0     -116.0
# 26  1561511871          0.5       218.0           0.5       -335.0     -335.0
# 27  1561603512         21.5      -121.0          21.5       -109.0     -121.0
# 28  1561603441         59.5      -117.0          59.5       -113.0     -117.0
# 29  1561511889          0.5       401.0           0.5       -856.0     -856.0
# 30  1561511847         24.5       102.0          24.5       -133.0     -133.0
# 31  1561603396          2.5       111.0           2.5       -148.0     -148.0
# 32  1561603457         48.5      -112.0          48.5       -118.0     -118.0
# 33  1561511865         14.5      -117.0          14.5       -113.0     -117.0
# 34  1561603363         13.5      -123.0          13.5       -107.0     -123.0
# 36  1561511856         33.5      -123.0          33.5       -108.0     -123.0
# 37  1561603393          2.5       128.0           2.5       -173.0     -173.0
# 39  1561528397         35.5      -121.0          35.5       -109.0     -121.0

# %%
nfl_df['player_name'] = nfl_df['prop_name'].apply(player_name)
nfl_df['prop_type'] = nfl_df['prop_name'].apply(prop_type)
nfl_df.drop(columns='prop_name', inplace=True)
nfl_df.drop_duplicates(inplace=True)

# %%
nfl_df
# Out:
#        prop_id     over_id    under_id  over_points  over_price  under_points  \
# 0   1561603507  1561603508  1561603509         19.5      -108.0          19.5
# 4   1561528424  1561528425  1561528426          0.5       226.0           0.5
# 5   1561603385  1561603386  1561603387         27.5      -112.0          27.5
# 6   1561603367  1561603368  1561603369         60.5      -113.0          60.5
# 7   1561603400  1561603401  1561603402         16.5      -119.0          16.5
# 8   1561603448  1561603449  1561603450          0.5       239.0           0.5
# 9   1561603388  1561603389  1561603390         16.5      -107.0          16.5
# 10  1561603442  1561603443  1561603444          0.5       165.0           0.5
# 11  1561603445  1561603446  1561603447         29.5      -125.0          29.5
# 12  1561603408  1561603409  1561603410          5.5      -118.0           5.5
# 13  1561511872  1561511873  1561511874          0.5       394.0           0.5
# 14  1561511884  1561511885  1561511886          0.5       427.0           0.5
# 15  1561528421  1561528422  1561528423         47.5      -118.0          47.5
# 16  1561603364  1561603365  1561603366         22.5      -115.0          22.5
# 17  1561511890  1561511891  1561511892          0.5       195.0           0.5
# 18  1561603370  1561603371  1561603372         23.5      -109.0          23.5
# 19  1561579441  1561579442  1561579443          0.5       148.0           0.5
# 20  1561603397  1561603398  1561603399         29.5      -114.0          29.5
# 21  1561511881  1561511882  1561511883          0.5      -126.0           0.5
# 22  1561511866  1561511867  1561511868         60.5      -112.0          60.5
# 24  1561603513  1561603514  1561603515         18.5      -106.0          18.5
# 25  1561603451  1561603452  1561603453         30.5      -114.0          30.5
# 26  1561511869  1561511870  1561511871          0.5       218.0           0.5
# 27  1561603510  1561603511  1561603512         21.5      -121.0          21.5
# 28  1561603439  1561603440  1561603441         59.5      -117.0          59.5
# 29  1561511887  1561511888  1561511889          0.5       401.0           0.5
# 30  1561511845  1561511846  1561511847         24.5       102.0          24.5
# 31  1561603394  1561603395  1561603396          2.5       111.0           2.5
# 32  1561603455  1561603456  1561603457         48.5      -112.0          48.5
# 33  1561511863  1561511864  1561511865         14.5      -117.0          14.5
# 34  1561603361  1561603362  1561603363         13.5      -123.0          13.5
# 36  1561511854  1561511855  1561511856         33.5      -123.0          33.5
# 37  1561603391  1561603392  1561603393          2.5       128.0           2.5
# 39  1561528395  1561528396  1561528397         35.5      -121.0          35.5
#
#     under_price  min_price       player_name        prop_type
# 0        -122.0     -122.0     rondale moore   long reception
# 4        -352.0     -352.0         zach ertz    td receptions
# 5        -118.0     -118.0    tre'quan smith    receiving yds
# 6        -117.0     -117.0       chris olave    receiving yds
# 7        -111.0     -119.0  marquez callaway   long reception
# 8        -392.0     -392.0      kyler murray          rush td
# 9        -124.0     -124.0    tre'quan smith   long reception
# 10       -236.0     -236.0   deandre hopkins    td receptions
# 11       -106.0     -125.0      kyler murray         rush yds
# 12       -112.0     -118.0    keith kirkwood    receiving yds
# 13       -832.0     -832.0    tre'quan smith    td receptions
# 14       -960.0     -960.0     juwan johnson    td receptions
# 15       -112.0     -118.0         zach ertz    receiving yds
# 16       -115.0     -115.0     juwan johnson    receiving yds
# 17       -289.0     -289.0       chris olave    td receptions
# 18       -121.0     -121.0       chris olave   long reception
# 19       -205.0     -205.0       taysom hill          rush td
# 20       -116.0     -116.0  marquez callaway    receiving yds
# 21       -105.0     -126.0      kyler murray    interceptions
# 22       -119.0     -119.0      alvin kamara         rush yds
# 24       -125.0     -125.0         zach ertz   long reception
# 25       -116.0     -116.0       taysom hill         rush yds
# 26       -335.0     -335.0      alvin kamara          rush td
# 27       -109.0     -121.0   deandre hopkins   long reception
# 28       -113.0     -117.0   deandre hopkins    receiving yds
# 29       -856.0     -856.0  marquez callaway    td receptions
# 30       -133.0     -133.0    mark ingram ii         rush yds
# 31       -148.0     -148.0  marquez callaway       receptions
# 32       -118.0     -118.0     rondale moore    receiving yds
# 33       -113.0     -117.0      alvin kamara   long reception
# 34       -107.0     -123.0     juwan johnson   long reception
# 36       -108.0     -123.0      alvin kamara    receiving yds
# 37       -173.0     -173.0    tre'quan smith       receptions
# 39       -109.0     -121.0      kyler murray  long completion

# %%
nfl_final = nfl_df.merge(dataframe, how='right', on=['player_name', 'prop_type'])
nfl_final.dropna(inplace = True)
nfl_final = nfl_final.sort_values(by = 'min_price', ascending = True)
nfl_final.drop(columns=['prop_id', 'over_id', 'under_id', 'under_points'], inplace=True)
nfl_final.rename(columns={'over_points':'pinnacle_line'}, inplace=True)
nfl_final['favored'] = np.where(nfl_final['min_price']==nfl_final['over_price'], 'over', 'under')
nfl_final.sort_values(by='min_price', inplace=True)

# %%
nfl_final
# Out:
#      pinnacle_line  over_price  under_price  min_price      player_name  \
# 629            0.5      -126.0       -105.0     -126.0     kyler murray
# 623           33.5      -123.0       -108.0     -123.0     alvin kamara
# 621           60.5      -112.0       -119.0     -119.0     alvin kamara
# 633           47.5      -118.0       -112.0     -118.0        zach ertz
# 632           59.5      -117.0       -113.0     -117.0  deandre hopkins
#
#          prop_type UnderDog Line favored
# 629  interceptions           0.5    over
# 623  receiving yds          34.5    over
# 621       rush yds          64.5   under
# 633  receiving yds          48.5    over
# 632  receiving yds          69.5    over

# %% [markdown]
# # Pinnacle MLB Scraping

# %%
# Opening JSON file
f = open(main_dir + "/Pinnacle/MLB/mlb_matchups.json")
  
# returns JSON object as 
# a dictionary
data = json.load(f)

# Iterating through the json
# list
player_props = []
#test = []
for i, d in enumerate(data['data']):
    try:
        if d['special']['category'].lower() == 'player props':
            data = {}
            data['prop_name'] = d['special']['description']
            data['prop_id'] = d['id']
            data['over_id'] = d['participants'][0]['id']
            data['under_id'] = d['participants'][1]['id']
            player_props.append(data)        
                
            
    except:
        continue

# Closing file
f.close()

# %%
# Opening JSON file
f = open(main_dir + "/Pinnacle/MLB/mlb_straight.json")
  
# returns JSON object as 
# a dictionary
data = json.load(f)
prop_prices = []
for d in data['data']:
    try:

        row = {}
        row['prop_id'] = d['matchupId']
    
        row['over_id'] = d['prices'][0]['participantId']
        row['over_points'] = d['prices'][0]['points']
        row['over_price'] = d['prices'][0]['price']
    
        row['under_id'] = d['prices'][1]['participantId']
        row['under_points'] = d['prices'][1]['points']
        row['under_price'] = d['prices'][1]['price']   
 
        prop_prices.append(row)
    
    except:
        continue


    
# Closing file
f.close()

# %%
mlb_propd = pd.DataFrame(player_props)
mlb_prices = pd.DataFrame(prop_prices)

# %%
mlb_df = pd.merge(mlb_propd, mlb_prices, how='left', on=['prop_id', 'over_id', 'under_id'])
mlb_df.dropna(inplace=True)
mlb_df['min_price'] = np.where(mlb_df['over_price']<=mlb_df['under_price'], 
                               mlb_df['over_price'], mlb_df['under_price'])

# %%
mlb_df['player_name'] = mlb_df['prop_name'].apply(player_name)
mlb_df['prop_type'] = mlb_df['prop_name'].apply(prop_type)
mlb_df.drop(columns='prop_name', inplace=True)
mlb_df.drop_duplicates(inplace=True)

# %%
mlb_final = mlb_df.merge(dataframe, how='right', on=['player_name', 'prop_type'])
mlb_final.dropna(inplace = True)
mlb_final = mlb_final.sort_values(by = 'min_price', ascending = True)
mlb_final.drop(columns=['prop_id', 'over_id', 'under_id', 'under_points'], inplace=True)
mlb_final.rename(columns={'over_points':'pinnacle_line'}, inplace=True)
mlb_final['favored'] = np.where(mlb_final['min_price']==mlb_final['over_price'], 'over', 'under')
mlb_final.sort_values(by='min_price', inplace=True)

# %%
mlb_final
# Out:
#      pinnacle_line  over_price  under_price  min_price       player_name  \
# 733            3.5      -164.0        122.0     -164.0   jameson taillon
# 741            5.5      -160.0        119.0     -160.0  justin verlander
# 727            6.5       104.0       -139.0     -139.0       blake snell
# 720            5.5      -133.0        101.0     -133.0        aaron nola
#
#             prop_type UnderDog Line favored
# 733  total strikeouts           4.0    over
# 741  total strikeouts           6.0    over
# 727  total strikeouts           6.0   under
# 720  total strikeouts           5.5    over

# %% [markdown]
# # Pinnacle NHL Scraping

# %%
# Opening JSON file
f = open(main_dir + "/Pinnacle/NHL/nhl_matchups.json")
  
# returns JSON object as 
# a dictionary
data = json.load(f)
  
# Iterating through the json
# list
player_props = []
#test = []
for i, d in enumerate(data['data']):
    try:
        if d['special']['category'].lower() == 'player props':
            data = {}
            data['prop_name'] = d['special']['description']
            data['prop_id'] = d['id']
            data['over_id'] = d['participants'][0]['id']
            data['under_id'] = d['participants'][1]['id']
            player_props.append(data)        
                
            
    except:
        continue

# Closing file
f.close()
#print(count)

# %%
# Opening JSON file
f = open(main_dir + "/Pinnacle/NHL/nhl_straight.json")
  
# returns JSON object as 
# a dictionary
data = json.load(f)
prop_prices = []
for d in data['data']:
    try:

        row = {}
        row['prop_id'] = d['matchupId']
    
        row['over_id'] = d['prices'][0]['participantId']
        row['over_points'] = d['prices'][0]['points']
        row['over_price'] = d['prices'][0]['price']
    
        row['under_id'] = d['prices'][1]['participantId']
        row['under_points'] = d['prices'][1]['points']
        row['under_price'] = d['prices'][1]['price']   
 
        prop_prices.append(row)
    
    except:
        continue


    
# Closing file
f.close()
#print(count)

# %%
nhl_propd = pd.DataFrame(player_props)
nhl_prices = pd.DataFrame(prop_prices)

# %%
nhl_df = pd.merge(nhl_propd, nhl_prices, how='left', on=['prop_id', 'over_id', 'under_id'])
nhl_df.dropna(inplace=True)
nhl_df['min_price'] = np.where(nhl_df['over_price']<=nhl_df['under_price'], 
                               nhl_df['over_price'], nhl_df['under_price'])

# %%
nhl_df['player_name'] = nhl_df['prop_name'].apply(player_name)
nhl_df['prop_type'] = nhl_df['prop_name'].apply(prop_type)

nhl_df.drop(columns='prop_name', inplace=True)
nhl_df.drop_duplicates(inplace=True)

# %%
nhl_final = nhl_df.merge(dataframe, how='right', on=['player_name', 'prop_type'])
nhl_final.dropna(inplace = True)
nhl_final = nhl_final.sort_values(by = 'min_price', ascending = True)
nhl_final.drop(columns=['prop_id', 'over_id', 'under_id', 'under_points'], inplace=True)
nhl_final.rename(columns={'over_points':'pinnacle_line'}, inplace=True)
nhl_final['favored'] = np.where(nhl_final['min_price']==nhl_final['over_price'], 'over', 'under')
nhl_final.sort_values(by='min_price', inplace=True)
nhl_final
# Out:
#      pinnacle_line  over_price  under_price  min_price         player_name  \
# 750            2.5       146.0       -202.0     -202.0       tony deangelo
# 768            2.5      -192.0        141.0     -192.0      mikko rantanen
# 749            2.5       140.0       -191.0     -191.0       ivan provorov
# 761            2.5      -190.0        139.0     -190.0         kyle connor
# 762            2.5       135.0       -184.0     -184.0       blake wheeler
# 767            2.5      -184.0        135.0     -184.0   valeri nichushkin
# 774            1.5      -184.0        135.0     -184.0       ryan o'reilly
# 754            2.5      -183.0        134.0     -183.0     matthew tkachuk
# 769            2.5      -182.0        135.0     -182.0          cale makar
# 755            2.5      -181.0        134.0     -181.0         sam bennett
# 763            2.5       130.0       -177.0     -177.0      mark scheifele
# 748            2.5       128.0       -174.0     -174.0  james van riemsdyk
# 760            3.5       118.0       -159.0     -159.0      nikolaj ehlers
# 766            0.5       115.0       -153.0     -153.0    nathan mackinnon
# 776            2.5       113.0       -151.0     -151.0    pavel buchnevich
# 765            4.5      -151.0        114.0     -151.0    nathan mackinnon
# 778            2.5       112.0       -149.0     -149.0        jared mccann
# 753            3.5       107.0       -143.0     -143.0   aleksander barkov
# 772            2.5       107.0       -142.0     -142.0        jordan kyrou
# 770            2.5      -135.0        102.0     -135.0      evan rodrigues
# 745            2.5      -134.0        101.0     -134.0      travis konecny
# 779            2.5      -132.0       -101.0     -132.0      jaden schwartz
# 756            2.5      -132.0        100.0     -132.0        sam reinhart
# 771            0.5      -128.0       -103.0     -128.0        jordan kyrou
# 751           25.5      -127.0       -104.0     -127.0    sergei bobrovsky
# 780            2.5      -127.0       -104.0     -127.0  oliver bjorkstrand
# 752            0.5      -127.0       -104.0     -127.0   aleksander barkov
# 764           26.5      -105.0       -126.0     -126.0  alexandar georgiev
# 746            0.5      -124.0       -107.0     -124.0      travis konecny
# 758            0.5      -107.0       -123.0     -123.0   pierre-luc dubois
# 773            2.5      -123.0       -108.0     -123.0  vladimir tarasenko
# 747            2.5      -108.0       -122.0     -122.0         kevin hayes
# 759            2.5      -109.0       -121.0     -121.0   pierre-luc dubois
# 777            0.5      -111.0       -120.0     -120.0        jared mccann
# 757           31.5      -119.0       -111.0     -119.0   connor hellebuyck
#
#          prop_type UnderDog Line favored
# 750  shots on goal           2.0   under
# 768  shots on goal           3.0    over
# 749  shots on goal           2.0   under
# 761  shots on goal           3.0    over
# 762  shots on goal           2.0   under
# 767  shots on goal           3.0    over
# 774  shots on goal           2.0    over
# 754  shots on goal           3.0    over
# 769  shots on goal           3.0    over
# 755  shots on goal           3.0    over
# 763  shots on goal           2.0   under
# 748  shots on goal           2.0   under
# 760  shots on goal           3.0   under
# 766          goals           0.5   under
# 776  shots on goal           2.0   under
# 765  shots on goal           4.5    over
# 778  shots on goal           2.0   under
# 753  shots on goal           3.0   under
# 772  shots on goal           2.0   under
# 770  shots on goal           2.5    over
# 745  shots on goal           2.5    over
# 779  shots on goal           2.5    over
# 756  shots on goal           2.5    over
# 771         points           0.5    over
# 751          saves          26.5    over
# 780  shots on goal           2.5    over
# 752        assists           0.5    over
# 764          saves          26.5   under
# 746         points           0.5    over
# 758         points           0.5   under
# 773  shots on goal           2.5    over
# 747  shots on goal           2.5   under
# 759  shots on goal           2.5   under
# 777         points           0.5   under
# 757          saves          31.5    over

# %% [markdown]
# # All Sports Dataframe

# %%
full_df = nhl_final.append(nfl_final).append(mlb_final)
pd.set_option('display.max_rows',None)
full_df.sort_values(by = 'min_price', ascending = True)
# Out:
#      pinnacle_line  over_price  under_price  min_price         player_name  \
# 750            2.5       146.0       -202.0     -202.0       tony deangelo
# 768            2.5      -192.0        141.0     -192.0      mikko rantanen
# 749            2.5       140.0       -191.0     -191.0       ivan provorov
# 761            2.5      -190.0        139.0     -190.0         kyle connor
# 762            2.5       135.0       -184.0     -184.0       blake wheeler
# 767            2.5      -184.0        135.0     -184.0   valeri nichushkin
# 774            1.5      -184.0        135.0     -184.0       ryan o'reilly
# 754            2.5      -183.0        134.0     -183.0     matthew tkachuk
# 769            2.5      -182.0        135.0     -182.0          cale makar
# 755            2.5      -181.0        134.0     -181.0         sam bennett
# 763            2.5       130.0       -177.0     -177.0      mark scheifele
# 748            2.5       128.0       -174.0     -174.0  james van riemsdyk
# 733            3.5      -164.0        122.0     -164.0     jameson taillon
# 741            5.5      -160.0        119.0     -160.0    justin verlander
# 760            3.5       118.0       -159.0     -159.0      nikolaj ehlers
# 766            0.5       115.0       -153.0     -153.0    nathan mackinnon
# 776            2.5       113.0       -151.0     -151.0    pavel buchnevich
# 765            4.5      -151.0        114.0     -151.0    nathan mackinnon
# 778            2.5       112.0       -149.0     -149.0        jared mccann
# 753            3.5       107.0       -143.0     -143.0   aleksander barkov
# 772            2.5       107.0       -142.0     -142.0        jordan kyrou
# 727            6.5       104.0       -139.0     -139.0         blake snell
# 770            2.5      -135.0        102.0     -135.0      evan rodrigues
# 745            2.5      -134.0        101.0     -134.0      travis konecny
# 720            5.5      -133.0        101.0     -133.0          aaron nola
# 779            2.5      -132.0       -101.0     -132.0      jaden schwartz
# 756            2.5      -132.0        100.0     -132.0        sam reinhart
# 771            0.5      -128.0       -103.0     -128.0        jordan kyrou
# 751           25.5      -127.0       -104.0     -127.0    sergei bobrovsky
# 780            2.5      -127.0       -104.0     -127.0  oliver bjorkstrand
# 752            0.5      -127.0       -104.0     -127.0   aleksander barkov
# 629            0.5      -126.0       -105.0     -126.0        kyler murray
# 764           26.5      -105.0       -126.0     -126.0  alexandar georgiev
# 746            0.5      -124.0       -107.0     -124.0      travis konecny
# 773            2.5      -123.0       -108.0     -123.0  vladimir tarasenko
# 623           33.5      -123.0       -108.0     -123.0        alvin kamara
# 758            0.5      -107.0       -123.0     -123.0   pierre-luc dubois
# 747            2.5      -108.0       -122.0     -122.0         kevin hayes
# 759            2.5      -109.0       -121.0     -121.0   pierre-luc dubois
# 777            0.5      -111.0       -120.0     -120.0        jared mccann
# 621           60.5      -112.0       -119.0     -119.0        alvin kamara
# 757           31.5      -119.0       -111.0     -119.0   connor hellebuyck
# 633           47.5      -118.0       -112.0     -118.0           zach ertz
# 632           59.5      -117.0       -113.0     -117.0     deandre hopkins
#
#             prop_type UnderDog Line favored
# 750     shots on goal           2.0   under
# 768     shots on goal           3.0    over
# 749     shots on goal           2.0   under
# 761     shots on goal           3.0    over
# 762     shots on goal           2.0   under
# 767     shots on goal           3.0    over
# 774     shots on goal           2.0    over
# 754     shots on goal           3.0    over
# 769     shots on goal           3.0    over
# 755     shots on goal           3.0    over
# 763     shots on goal           2.0   under
# 748     shots on goal           2.0   under
# 733  total strikeouts           4.0    over
# 741  total strikeouts           6.0    over
# 760     shots on goal           3.0   under
# 766             goals           0.5   under
# 776     shots on goal           2.0   under
# 765     shots on goal           4.5    over
# 778     shots on goal           2.0   under
# 753     shots on goal           3.0   under
# 772     shots on goal           2.0   under
# 727  total strikeouts           6.0   under
# 770     shots on goal           2.5    over
# 745     shots on goal           2.5    over
# 720  total strikeouts           5.5    over
# 779     shots on goal           2.5    over
# 756     shots on goal           2.5    over
# 771            points           0.5    over
# 751             saves          26.5    over
# 780     shots on goal           2.5    over
# 752           assists           0.5    over
# 629     interceptions           0.5    over
# 764             saves          26.5   under
# 746            points           0.5    over
# 773     shots on goal           2.5    over
# 623     receiving yds          34.5    over
# 758            points           0.5   under
# 747     shots on goal           2.5   under
# 759     shots on goal           2.5   under
# 777            points           0.5   under
# 621          rush yds          64.5   under
# 757             saves          31.5    over
# 633     receiving yds          48.5    over
# 632     receiving yds          69.5    over

# %% [markdown]
# # Dropping Buffered Lines

# %%
#equal_lines_df = full_df.loc[full_df['pinnacle_line']!=full_df['UnderDog Line']]
#equal_lines_df.sort_values(by = 'min_price', ascending = True)
