# %%
import requests
import pprint
pp = pprint.PrettyPrinter(indent=4)
import numpy as np
import pandas as pd
import json
import re
import os, sys

# %%
main_dir = os.path.normpath(os.getcwd() + os.sep + os.pardir)

# %% [markdown]
# # Functions That Will Be Called

# %%
def prop_type(string):
    type_ = re.findall('(.+?)\(', string)[1].lower().strip(')')
    return type_

def player_name(string):
    name = re.findall('(.+?)\(', string)[0].lower().strip()
    return name

# %%
def get_picks(pp, pin, league):
    df = pp[pp['league']==league]
    df = df.merge(pin, how='left', on=['player_name', 'prop_type'])
    df.dropna(inplace=True)
    df.drop(columns=['prop_id', 'over_id', 'under_id', 'under_points'], inplace=True)
    df.rename(columns={'over_points':'pinnacle_line'}, inplace=True)
    
    df['favored'] = np.where(df['min_price']==df['over_price'], 'over', 'under')
    
    df['edge'] = np.where((df['pinnacle_line']<df['pp_line'])&(df['favored']=='under'), 'edge',
                         np.where((df['pinnacle_line']>df['pp_line'])&(df['favored']=='over'), 'edge',
                                 np.where(df['pinnacle_line']==df['pp_line'], 'equal',
                                         np.where((df['pinnacle_line']<df['pp_line'])&(df['favored']=='over'), 'buffer',
                                                 np.where((df['pinnacle_line']>df['pp_line'])&(df['favored']=='under'), 'buffer', 'else')))))
    df.sort_values(by='min_price', inplace=True)
    return df

def matchup_cleaning(data):
    player_props = []
    for i, d in enumerate(data['data']):
        try:
            if d['special']['category'].lower() == 'player props':
                data = {}
                data['prop_name'] = d['special']['description']
                data['prop_id'] = d['id']
                data['over_id'] = d['participants'][0]['id']
                data['under_id'] = d['participants'][1]['id']
                player_props.append(data)        
                
            
        except:
            continue
    return player_props


def straight_cleaning(data):
    prop_prices = []
    for d in data['data']:
        try:

            row = {}
            row['prop_id'] = d['matchupId']

            row['over_id'] = d['prices'][0]['participantId']
            row['over_points'] = d['prices'][0]['points']
            row['over_price'] = d['prices'][0]['price']

            row['under_id'] = d['prices'][1]['participantId']
            row['under_points'] = d['prices'][1]['points']
            row['under_price'] = d['prices'][1]['price']   

            prop_prices.append(row)

        except:
            continue
    return prop_prices

def df_manipulation(player_props,prop_prices):
    prop_df = pd.DataFrame(player_props)
    prices_df = pd.DataFrame(prop_prices)
    
    temp_df = pd.merge(prop_df, prices_df, how='left', on=['prop_id', 'over_id', 'under_id'])
    temp_df.dropna(inplace=True)
    temp_df['min_price'] = np.where(temp_df['over_price']<=temp_df['under_price'], 
                                   temp_df['over_price'], temp_df['under_price'])
    
    temp_df['player_name'] = temp_df['prop_name'].apply(player_name)
    temp_df['prop_type'] = temp_df['prop_name'].apply(prop_type)
    temp_df.drop(columns='prop_name', inplace=True)
    temp_df.drop_duplicates(inplace=True)
    
    return temp_df

# %% [markdown]
# # Prize Picks Projections Scrape

# %%
f = open(main_dir + "/PrizePicks/projections.json")
data = json.load(f)
pp = pd.json_normalize(data['included'])
pp1 = pp[pp['type'] == 'new_player']
pp2 = pd.json_normalize(data['data'])

pp1 = pp1.rename(columns = {'id' : 'playerid'})
pp2 = pp2.rename(columns = {'relationships.new_player.data.id' : 'playerid'})

mergedDF = pp2.merge(pp1, on = 'playerid', how = 'left')

fdf = mergedDF[['attributes.line_score','attributes.stat_type','attributes.name','attributes.league']]

# %%
fdf.rename(columns={'attributes.line_score':'pp_line', 'attributes.stat_type':'prop_type', 'attributes.name':'player_name', 
                   'attributes.league':'league'}, inplace=True)
fdf['player_name'] = fdf['player_name'].str.lower()
fdf['league'] = fdf['league'].str.lower()
fdf['prop_type'] = fdf['prop_type'].str.lower()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
# changing prop types to match pinnacle
# keep adding to this until complete

# MLB PROPS
fdf['prop_type'] = np.where(fdf['prop_type']=='earned runs allowed', 'earned runs',
                           np.where(fdf['prop_type']=='strikeouts', 'total strikeouts',
                                   fdf['prop_type']))

#NFL Props
fdf['prop_type'] = np.where(fdf['prop_type']=='pass yards', 'pass yds', 
                           np.where(fdf['prop_type']=='receiving yards', 'receiving yds', 
                                    np.where(fdf['prop_type']=='rush yards', 'rush yds',
                                            fdf['prop_type'])))

#NHL Props
fdf['prop_type'] = np.where(fdf['prop_type']=='goalie saves', 'saves', fdf['prop_type'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # Pinnacle NFL Scraping

# %%
f = open(main_dir + "/Pinnacle/NFL/nfl_matchups.json")

data = json.load(f)
player_props = matchup_cleaning(data)

f.close()

# %%
f = open(main_dir + "/Pinnacle/NFL/nfl_straight.json")

data = json.load(f)
prop_prices = straight_cleaning(data)

f.close()

# %%
nfl_df = df_manipulation(player_props,prop_prices)

# %%
nfl = get_picks(fdf, nfl_df, 'nfl')
nfl.sort_values(by='min_price', ascending=True)
# Out:
#      pp_line      prop_type          player_name league  pinnacle_line  \
# 36       2.0     receptions       tre'quan smith    nfl            2.5
# 39       2.0     receptions           a.j. green    nfl            2.5
# 94     223.5       pass yds      taylor heinicke    nfl          223.5
# 34       5.0     receptions        rondale moore    nfl            4.5
# 40      22.5  receiving yds        juwan johnson    nfl           25.5
# 24      30.5       rush yds          taysom hill    nfl           32.5
# 22       5.0     receptions            zach ertz    nfl            4.5
# 41       2.0     receptions        juwan johnson    nfl            2.5
# 38      25.5  receiving yds           a.j. green    nfl           24.5
# 127     13.5       rush yds      trevor lawrence    nfl           13.5
# 122     20.5       rush yds        rachaad white    nfl           20.5
# 8       32.5       rush yds         kyler murray    nfl           33.5
# 19       4.5     receptions          chris olave    nfl            4.5
# 115     56.5       rush yds  christian mccaffrey    nfl           55.5
# 26      59.5  receiving yds      deandre hopkins    nfl           61.5
# 95      10.5       rush yds      taylor heinicke    nfl           10.5
# 98      55.5       rush yds          aaron jones    nfl           54.5
# 27       5.0     receptions      deandre hopkins    nfl            5.5
# 4       34.5  pass attempts         kyler murray    nfl           35.5
# 43       5.5  receiving yds       keith kirkwood    nfl            4.5
# 103     53.5  receiving yds       terry mclaurin    nfl           50.5
# 0      216.5       pass yds          andy dalton    nfl          216.5
# 12      32.5  receiving yds         alvin kamara    nfl           33.5
# 30       2.0     receptions     marquez callaway    nfl            2.5
# 136     11.5       rush yds      jacoby brissett    nfl           11.5
# 29      29.5  receiving yds     marquez callaway    nfl           28.5
# 147     75.5  receiving yds         mark andrews    nfl           70.5
# 138    215.5       pass yds      jacoby brissett    nfl          215.5
# 166     60.5  receiving yds        brandin cooks    nfl           62.5
# 145     53.5  receiving yds         amari cooper    nfl           53.5
# 134     49.5  receiving yds       christian kirk    nfl           49.5
# 128     76.5       rush yds       saquon barkley    nfl           76.5
# 130     48.5       rush yds       travis etienne    nfl           48.5
# 123    190.5       pass yds         daniel jones    nfl          194.5
# 18      60.5  receiving yds          chris olave    nfl           59.5
# 21      47.5  receiving yds            zach ertz    nfl           45.5
# 11      62.5       rush yds         alvin kamara    nfl           61.5
# 125    225.5       pass yds      trevor lawrence    nfl          227.5
# 141     80.5       rush yds           nick chubb    nfl           77.5
# 157    230.5       pass yds          davis mills    nfl          230.5
# 117     65.5  receiving yds           mike evans    nfl           66.5
# 102     52.5  receiving yds         allen lazard    nfl           51.5
# 110    267.5       pass yds            tom brady    nfl          268.5
# 121     63.5  receiving yds         chris godwin    nfl           64.5
# 139    212.5       pass yds        lamar jackson    nfl          217.5
# 159    250.5       pass yds           derek carr    nfl          251.5
# 162     67.5       rush yds        dameon pierce    nfl           65.5
# 32      48.5  receiving yds        rondale moore    nfl           46.5
# 37      27.5  receiving yds       tre'quan smith    nfl           26.5
# 114     65.5       rush yds    leonard fournette    nfl           65.5
# 97      21.5  receiving yds          aaron jones    nfl           21.5
# 53     280.5       pass yds           joe burrow    nfl          285.5
# 52      34.5       rush yds       marcus mariota    nfl           34.5
# 50     190.5       pass yds       marcus mariota    nfl          193.5
# 169     80.5  receiving yds        davante adams    nfl           78.5
#
#      over_price  under_price  min_price favored    edge
# 36        129.0       -175.0     -175.0   under  buffer
# 39        129.0       -173.0     -173.0   under  buffer
# 94        120.0       -158.0     -158.0   under   equal
# 34       -157.0        117.0     -157.0    over  buffer
# 40       -151.0        114.0     -151.0    over    edge
# 24        109.0       -144.0     -144.0   under  buffer
# 22       -141.0        107.0     -141.0    over  buffer
# 41        105.0       -140.0     -140.0   under  buffer
# 38        105.0       -139.0     -139.0   under    edge
# 127       105.0       -139.0     -139.0   under   equal
# 122       104.0       -138.0     -138.0   under   equal
# 8        -135.0        102.0     -135.0    over    edge
# 19        100.0       -133.0     -133.0   under   equal
# 115      -100.0       -132.0     -132.0   under    edge
# 26       -131.0       -101.0     -131.0    over    edge
# 95       -131.0       -101.0     -131.0    over   equal
# 98       -101.0       -131.0     -131.0   under    edge
# 27       -104.0       -128.0     -128.0   under  buffer
# 4        -104.0       -127.0     -127.0   under  buffer
# 43       -105.0       -126.0     -126.0   under    edge
# 103      -105.0       -125.0     -125.0   under    edge
# 0        -106.0       -124.0     -124.0   under   equal
# 12       -124.0       -106.0     -124.0    over    edge
# 30       -109.0       -123.0     -123.0   under  buffer
# 136      -122.0       -108.0     -122.0    over   equal
# 29       -118.0       -112.0     -118.0    over  buffer
# 147      -117.0       -113.0     -117.0    over  buffer
# 138      -113.0       -117.0     -117.0   under   equal
# 166      -113.0       -117.0     -117.0   under  buffer
# 145      -117.0       -113.0     -117.0    over   equal
# 134      -117.0       -113.0     -117.0    over   equal
# 128      -117.0       -113.0     -117.0    over   equal
# 130      -117.0       -113.0     -117.0    over   equal
# 123      -113.0       -117.0     -117.0   under  buffer
# 18       -117.0       -113.0     -117.0    over  buffer
# 21       -116.0       -114.0     -116.0    over  buffer
# 11       -116.0       -114.0     -116.0    over  buffer
# 125      -116.0       -114.0     -116.0    over    edge
# 141      -114.0       -116.0     -116.0   under    edge
# 157      -114.0       -116.0     -116.0   under   equal
# 117      -116.0       -114.0     -116.0    over    edge
# 102      -114.0       -116.0     -116.0   under    edge
# 110      -114.0       -116.0     -116.0   under  buffer
# 121      -116.0       -114.0     -116.0    over    edge
# 139      -115.0       -115.0     -115.0    over    edge
# 159      -115.0       -115.0     -115.0    over    edge
# 162      -115.0       -115.0     -115.0    over  buffer
# 32       -115.0       -115.0     -115.0    over  buffer
# 37       -115.0       -115.0     -115.0    over  buffer
# 114      -115.0       -115.0     -115.0    over   equal
# 97       -115.0       -115.0     -115.0    over   equal
# 53       -115.0       -115.0     -115.0    over    edge
# 52       -115.0       -115.0     -115.0    over   equal
# 50       -115.0       -115.0     -115.0    over    edge
# 169      -115.0       -115.0     -115.0    over  buffer

# %% [markdown]
# # Pinnacle MLB Scraping

# %%
f = open(main_dir + "/Pinnacle/MLB/mlb_matchups.json")
  
data = json.load(f)
player_props = matchup_cleaning(data)

f.close()

# %%
f = open(main_dir + "/Pinnacle/MLB/mlb_straight.json")
  
data = json.load(f)
prop_prices = straight_cleaning(data)

f.close()

# %%
mlb_df = df_manipulation(player_props, prop_prices)

# %%
mlb = get_picks(fdf, mlb_df, 'mlb')
mlb.sort_values(by='min_price', ascending=True)
# Out:
#    pp_line     prop_type     player_name league  pinnacle_line  over_price  \
# 5      5.0  hits allowed  framber valdez    mlb            5.5       127.0
# 0      2.0   earned runs   luis severino    mlb            1.5      -167.0
# 3      2.0   earned runs  framber valdez    mlb            2.5       118.0
# 1      4.5  hits allowed   luis severino    mlb            4.5       106.0
#
#    under_price  min_price favored    edge
# 5       -173.0     -173.0   under  buffer
# 0        124.0     -167.0    over  buffer
# 3       -158.0     -158.0   under  buffer
# 1       -142.0     -142.0   under   equal

# %% [markdown]
# # Pinnacle NHL Scraping

# %%
f = open(main_dir + "/Pinnacle/NHL/nhl_matchups.json")
  
data = json.load(f)
player_props = matchup_cleaning(data)

f.close()

# %%
f = open(main_dir + "/Pinnacle/NHL/nhl_straight.json")
  
data = json.load(f)
prop_prices = straight_cleaning(data)

f.close()

# %%
nhl_df = df_manipulation(player_props, prop_prices)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/9s/f_wwnnxn1x54pvjy5pjkrmxh0000gn/T/ipykernel_9094/1519307031.py in <module>
# ----> 1 nhl_df = df_manipulation(player_props, prop_prices)
#
# /var/folders/9s/f_wwnnxn1x54pvjy5pjkrmxh0000gn/T/ipykernel_9094/4121825375.py in df_manipulation(player_props, prop_prices)
#      60     prices_df = pd.DataFrame(prop_prices)
#      61
# ---> 62     temp_df = pd.merge(prop_df, prices_df, how='left', on=['prop_id', 'over_id', 'under_id'])
#      63     temp_df.dropna(inplace=True)
#      64     temp_df['min_price'] = np.where(temp_df['over_price']<=temp_df['under_price'],
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     117         copy=copy,
#     118         indicator=indicator,
# --> 119         validate=validate,
#     120     )
#     121     return op.get_result()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
#     701         # validate the merge keys dtypes. We may need to coerce
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1107                         right_keys.append(rk)
#    1108                     if lk is not None:
# -> 1109                         left_keys.append(left._get_label_or_level_values(lk))
#    1110                         join_names.append(lk)
#    1111                     else:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'prop_id'

# %%
nhl = get_picks(fdf, nhl_df, 'nhl')
nhl.sort_values(by='min_price', ascending=True)
# Out:
# Empty DataFrame
# Columns: [pp_line, league, pinnacle_line, over_price, under_price, min_price, player_name, prop_type, favored, edge]
# Index: []

# %% [markdown]
# # Pinnacle NBA Scraping

# %%
# Opening JSON file
f = open(main_dir + "/Pinnacle/NBA/nba_matchups.json")

data = json.load(f)
player_props = matchup_cleaning(data)

f.close()

# %%
f = open(main_dir + "/Pinnacle/NBA/nba_straight.json")
  
data = json.load(f)
prop_prices = straight_cleaning(data)

f.close()

# %%
nba_df = df_manipulation(player_props, prop_prices)

# %%
nba = get_picks(fdf, nba_df, 'nba')
nba.sort_values(by='min_price', ascending=True)
# Out:
#     pp_line prop_type            player_name league  pinnacle_line  \
# 9       6.0  rebounds           james harden    nba            6.5
# 11      4.5  rebounds            brook lopez    nba            4.5
# 17      2.5   assists          tobias harris    nba            2.5
# 3      11.0  rebounds            joel embiid    nba           11.5
# 10      9.5   assists           james harden    nba            9.5
# 14      2.5  rebounds           tyrese maxey    nba            2.5
# 7      19.5    points           jrue holiday    nba           19.5
# 1      11.5  rebounds  giannis antetokounmpo    nba           11.5
# 5       4.5  rebounds           jrue holiday    nba            4.5
# 0      30.5    points  giannis antetokounmpo    nba           30.5
# 4      26.5    points            joel embiid    nba           26.5
# 2       3.5   assists            joel embiid    nba            3.5
# 6       6.5   assists           jrue holiday    nba            6.5
# 16      5.5  rebounds          tobias harris    nba            5.5
# 13     18.5    points           tyrese maxey    nba           18.5
# 15     14.5    points          tobias harris    nba           14.5
# 8      22.5    points           james harden    nba           22.5
# 12     11.5    points            brook lopez    nba           11.5
#
#     over_price  under_price  min_price favored    edge
# 9        118.0       -159.0     -159.0   under  buffer
# 11      -145.0        109.0     -145.0    over   equal
# 17      -138.0        104.0     -138.0    over   equal
# 3        103.0       -136.0     -136.0   under  buffer
# 10       103.0       -136.0     -136.0   under   equal
# 14      -133.0        100.0     -133.0    over   equal
# 7       -103.0       -129.0     -129.0   under   equal
# 1       -126.0       -105.0     -126.0    over   equal
# 5       -126.0       -105.0     -126.0    over   equal
# 0       -126.0       -105.0     -126.0    over   equal
# 4       -108.0       -123.0     -123.0   under   equal
# 2       -110.0       -121.0     -121.0   under   equal
# 6       -121.0       -110.0     -121.0    over   equal
# 16      -118.0       -113.0     -118.0    over   equal
# 13      -118.0       -112.0     -118.0    over   equal
# 15      -116.0       -114.0     -116.0    over   equal
# 8       -116.0       -114.0     -116.0    over   equal
# 12      -115.0       -115.0     -115.0    over   equal

# %% [markdown]
# # All Sports Dataframe

# %%
full_df = nhl.append(nfl).append(mlb).append(nba)
pd.set_option('display.max_rows',None)
full_df.sort_values(by = 'min_price', ascending = True)
# Out:
#      pp_line league  pinnacle_line  over_price  under_price  min_price  \
# 36       2.0    nfl            2.5       129.0       -175.0     -175.0
# 5        5.0    mlb            5.5       127.0       -173.0     -173.0
# 39       2.0    nfl            2.5       129.0       -173.0     -173.0
# 0        2.0    mlb            1.5      -167.0        124.0     -167.0
# 9        6.0    nba            6.5       118.0       -159.0     -159.0
# 94     223.5    nfl          223.5       120.0       -158.0     -158.0
# 3        2.0    mlb            2.5       118.0       -158.0     -158.0
# 34       5.0    nfl            4.5      -157.0        117.0     -157.0
# 40      22.5    nfl           25.5      -151.0        114.0     -151.0
# 11       4.5    nba            4.5      -145.0        109.0     -145.0
# 24      30.5    nfl           32.5       109.0       -144.0     -144.0
# 1        4.5    mlb            4.5       106.0       -142.0     -142.0
# 22       5.0    nfl            4.5      -141.0        107.0     -141.0
# 41       2.0    nfl            2.5       105.0       -140.0     -140.0
# 127     13.5    nfl           13.5       105.0       -139.0     -139.0
# 38      25.5    nfl           24.5       105.0       -139.0     -139.0
# 122     20.5    nfl           20.5       104.0       -138.0     -138.0
# 17       2.5    nba            2.5      -138.0        104.0     -138.0
# 10       9.5    nba            9.5       103.0       -136.0     -136.0
# 3       11.0    nba           11.5       103.0       -136.0     -136.0
# 8       32.5    nfl           33.5      -135.0        102.0     -135.0
# 19       4.5    nfl            4.5       100.0       -133.0     -133.0
# 14       2.5    nba            2.5      -133.0        100.0     -133.0
# 115     56.5    nfl           55.5      -100.0       -132.0     -132.0
# 26      59.5    nfl           61.5      -131.0       -101.0     -131.0
# 98      55.5    nfl           54.5      -101.0       -131.0     -131.0
# 95      10.5    nfl           10.5      -131.0       -101.0     -131.0
# 7       19.5    nba           19.5      -103.0       -129.0     -129.0
# 27       5.0    nfl            5.5      -104.0       -128.0     -128.0
# 4       34.5    nfl           35.5      -104.0       -127.0     -127.0
# 0       30.5    nba           30.5      -126.0       -105.0     -126.0
# 43       5.5    nfl            4.5      -105.0       -126.0     -126.0
# 5        4.5    nba            4.5      -126.0       -105.0     -126.0
# 1       11.5    nba           11.5      -126.0       -105.0     -126.0
# 103     53.5    nfl           50.5      -105.0       -125.0     -125.0
# 12      32.5    nfl           33.5      -124.0       -106.0     -124.0
# 0      216.5    nfl          216.5      -106.0       -124.0     -124.0
# 30       2.0    nfl            2.5      -109.0       -123.0     -123.0
# 4       26.5    nba           26.5      -108.0       -123.0     -123.0
# 136     11.5    nfl           11.5      -122.0       -108.0     -122.0
# 6        6.5    nba            6.5      -121.0       -110.0     -121.0
# 2        3.5    nba            3.5      -110.0       -121.0     -121.0
# 16       5.5    nba            5.5      -118.0       -113.0     -118.0
# 29      29.5    nfl           28.5      -118.0       -112.0     -118.0
# 13      18.5    nba           18.5      -118.0       -112.0     -118.0
# 130     48.5    nfl           48.5      -117.0       -113.0     -117.0
# 138    215.5    nfl          215.5      -113.0       -117.0     -117.0
# 166     60.5    nfl           62.5      -113.0       -117.0     -117.0
# 147     75.5    nfl           70.5      -117.0       -113.0     -117.0
# 145     53.5    nfl           53.5      -117.0       -113.0     -117.0
# 18      60.5    nfl           59.5      -117.0       -113.0     -117.0
# 128     76.5    nfl           76.5      -117.0       -113.0     -117.0
# 123    190.5    nfl          194.5      -113.0       -117.0     -117.0
# 134     49.5    nfl           49.5      -117.0       -113.0     -117.0
# 15      14.5    nba           14.5      -116.0       -114.0     -116.0
# 121     63.5    nfl           64.5      -116.0       -114.0     -116.0
# 21      47.5    nfl           45.5      -116.0       -114.0     -116.0
# 110    267.5    nfl          268.5      -114.0       -116.0     -116.0
# 102     52.5    nfl           51.5      -114.0       -116.0     -116.0
# 117     65.5    nfl           66.5      -116.0       -114.0     -116.0
# 8       22.5    nba           22.5      -116.0       -114.0     -116.0
# 141     80.5    nfl           77.5      -114.0       -116.0     -116.0
# 125    225.5    nfl          227.5      -116.0       -114.0     -116.0
# 11      62.5    nfl           61.5      -116.0       -114.0     -116.0
# 157    230.5    nfl          230.5      -114.0       -116.0     -116.0
# 169     80.5    nfl           78.5      -115.0       -115.0     -115.0
# 139    212.5    nfl          217.5      -115.0       -115.0     -115.0
# 162     67.5    nfl           65.5      -115.0       -115.0     -115.0
# 32      48.5    nfl           46.5      -115.0       -115.0     -115.0
# 37      27.5    nfl           26.5      -115.0       -115.0     -115.0
# 114     65.5    nfl           65.5      -115.0       -115.0     -115.0
# 97      21.5    nfl           21.5      -115.0       -115.0     -115.0
# 53     280.5    nfl          285.5      -115.0       -115.0     -115.0
# 52      34.5    nfl           34.5      -115.0       -115.0     -115.0
# 50     190.5    nfl          193.5      -115.0       -115.0     -115.0
# 159    250.5    nfl          251.5      -115.0       -115.0     -115.0
# 12      11.5    nba           11.5      -115.0       -115.0     -115.0
#
#                player_name      prop_type favored    edge
# 36          tre'quan smith     receptions   under  buffer
# 5           framber valdez   hits allowed   under  buffer
# 39              a.j. green     receptions   under  buffer
# 0            luis severino    earned runs    over  buffer
# 9             james harden       rebounds   under  buffer
# 94         taylor heinicke       pass yds   under   equal
# 3           framber valdez    earned runs   under  buffer
# 34           rondale moore     receptions    over  buffer
# 40           juwan johnson  receiving yds    over    edge
# 11             brook lopez       rebounds    over   equal
# 24             taysom hill       rush yds   under  buffer
# 1            luis severino   hits allowed   under   equal
# 22               zach ertz     receptions    over  buffer
# 41           juwan johnson     receptions   under  buffer
# 127        trevor lawrence       rush yds   under   equal
# 38              a.j. green  receiving yds   under    edge
# 122          rachaad white       rush yds   under   equal
# 17           tobias harris        assists    over   equal
# 10            james harden        assists   under   equal
# 3              joel embiid       rebounds   under  buffer
# 8             kyler murray       rush yds    over    edge
# 19             chris olave     receptions   under   equal
# 14            tyrese maxey       rebounds    over   equal
# 115    christian mccaffrey       rush yds   under    edge
# 26         deandre hopkins  receiving yds    over    edge
# 98             aaron jones       rush yds   under    edge
# 95         taylor heinicke       rush yds    over   equal
# 7             jrue holiday         points   under   equal
# 27         deandre hopkins     receptions   under  buffer
# 4             kyler murray  pass attempts   under  buffer
# 0    giannis antetokounmpo         points    over   equal
# 43          keith kirkwood  receiving yds   under    edge
# 5             jrue holiday       rebounds    over   equal
# 1    giannis antetokounmpo       rebounds    over   equal
# 103         terry mclaurin  receiving yds   under    edge
# 12            alvin kamara  receiving yds    over    edge
# 0              andy dalton       pass yds   under   equal
# 30        marquez callaway     receptions   under  buffer
# 4              joel embiid         points   under   equal
# 136        jacoby brissett       rush yds    over   equal
# 6             jrue holiday        assists    over   equal
# 2              joel embiid        assists   under   equal
# 16           tobias harris       rebounds    over   equal
# 29        marquez callaway  receiving yds    over  buffer
# 13            tyrese maxey         points    over   equal
# 130         travis etienne       rush yds    over   equal
# 138        jacoby brissett       pass yds   under   equal
# 166          brandin cooks  receiving yds   under  buffer
# 147           mark andrews  receiving yds    over  buffer
# 145           amari cooper  receiving yds    over   equal
# 18             chris olave  receiving yds    over  buffer
# 128         saquon barkley       rush yds    over   equal
# 123           daniel jones       pass yds   under  buffer
# 134         christian kirk  receiving yds    over   equal
# 15           tobias harris         points    over   equal
# 121           chris godwin  receiving yds    over    edge
# 21               zach ertz  receiving yds    over  buffer
# 110              tom brady       pass yds   under  buffer
# 102           allen lazard  receiving yds   under    edge
# 117             mike evans  receiving yds    over    edge
# 8             james harden         points    over   equal
# 141             nick chubb       rush yds   under    edge
# 125        trevor lawrence       pass yds    over    edge
# 11            alvin kamara       rush yds    over  buffer
# 157            davis mills       pass yds   under   equal
# 169          davante adams  receiving yds    over  buffer
# 139          lamar jackson       pass yds    over    edge
# 162          dameon pierce       rush yds    over  buffer
# 32           rondale moore  receiving yds    over  buffer
# 37          tre'quan smith  receiving yds    over  buffer
# 114      leonard fournette       rush yds    over   equal
# 97             aaron jones  receiving yds    over   equal
# 53              joe burrow       pass yds    over    edge
# 52          marcus mariota       rush yds    over   equal
# 50          marcus mariota       pass yds    over    edge
# 159             derek carr       pass yds    over    edge
# 12             brook lopez         points    over   equal

# %% [markdown]
# # Dropping Buffered Lines

# %%
equal_lines_df = full_df.loc[full_df['edge']!='buffer']
equal_lines_df.sort_values(by = 'min_price', ascending = True)
# Out:
#      pp_line league  pinnacle_line  over_price  under_price  min_price  \
# 94     223.5    nfl          223.5       120.0       -158.0     -158.0
# 40      22.5    nfl           25.5      -151.0        114.0     -151.0
# 11       4.5    nba            4.5      -145.0        109.0     -145.0
# 1        4.5    mlb            4.5       106.0       -142.0     -142.0
# 127     13.5    nfl           13.5       105.0       -139.0     -139.0
# 38      25.5    nfl           24.5       105.0       -139.0     -139.0
# 17       2.5    nba            2.5      -138.0        104.0     -138.0
# 122     20.5    nfl           20.5       104.0       -138.0     -138.0
# 10       9.5    nba            9.5       103.0       -136.0     -136.0
# 8       32.5    nfl           33.5      -135.0        102.0     -135.0
# 14       2.5    nba            2.5      -133.0        100.0     -133.0
# 19       4.5    nfl            4.5       100.0       -133.0     -133.0
# 115     56.5    nfl           55.5      -100.0       -132.0     -132.0
# 95      10.5    nfl           10.5      -131.0       -101.0     -131.0
# 98      55.5    nfl           54.5      -101.0       -131.0     -131.0
# 26      59.5    nfl           61.5      -131.0       -101.0     -131.0
# 7       19.5    nba           19.5      -103.0       -129.0     -129.0
# 1       11.5    nba           11.5      -126.0       -105.0     -126.0
# 0       30.5    nba           30.5      -126.0       -105.0     -126.0
# 5        4.5    nba            4.5      -126.0       -105.0     -126.0
# 43       5.5    nfl            4.5      -105.0       -126.0     -126.0
# 103     53.5    nfl           50.5      -105.0       -125.0     -125.0
# 12      32.5    nfl           33.5      -124.0       -106.0     -124.0
# 0      216.5    nfl          216.5      -106.0       -124.0     -124.0
# 4       26.5    nba           26.5      -108.0       -123.0     -123.0
# 136     11.5    nfl           11.5      -122.0       -108.0     -122.0
# 6        6.5    nba            6.5      -121.0       -110.0     -121.0
# 2        3.5    nba            3.5      -110.0       -121.0     -121.0
# 13      18.5    nba           18.5      -118.0       -112.0     -118.0
# 16       5.5    nba            5.5      -118.0       -113.0     -118.0
# 145     53.5    nfl           53.5      -117.0       -113.0     -117.0
# 138    215.5    nfl          215.5      -113.0       -117.0     -117.0
# 128     76.5    nfl           76.5      -117.0       -113.0     -117.0
# 134     49.5    nfl           49.5      -117.0       -113.0     -117.0
# 130     48.5    nfl           48.5      -117.0       -113.0     -117.0
# 15      14.5    nba           14.5      -116.0       -114.0     -116.0
# 125    225.5    nfl          227.5      -116.0       -114.0     -116.0
# 157    230.5    nfl          230.5      -114.0       -116.0     -116.0
# 8       22.5    nba           22.5      -116.0       -114.0     -116.0
# 141     80.5    nfl           77.5      -114.0       -116.0     -116.0
# 121     63.5    nfl           64.5      -116.0       -114.0     -116.0
# 117     65.5    nfl           66.5      -116.0       -114.0     -116.0
# 102     52.5    nfl           51.5      -114.0       -116.0     -116.0
# 50     190.5    nfl          193.5      -115.0       -115.0     -115.0
# 52      34.5    nfl           34.5      -115.0       -115.0     -115.0
# 53     280.5    nfl          285.5      -115.0       -115.0     -115.0
# 97      21.5    nfl           21.5      -115.0       -115.0     -115.0
# 114     65.5    nfl           65.5      -115.0       -115.0     -115.0
# 159    250.5    nfl          251.5      -115.0       -115.0     -115.0
# 139    212.5    nfl          217.5      -115.0       -115.0     -115.0
# 12      11.5    nba           11.5      -115.0       -115.0     -115.0
#
#                player_name      prop_type favored   edge
# 94         taylor heinicke       pass yds   under  equal
# 40           juwan johnson  receiving yds    over   edge
# 11             brook lopez       rebounds    over  equal
# 1            luis severino   hits allowed   under  equal
# 127        trevor lawrence       rush yds   under  equal
# 38              a.j. green  receiving yds   under   edge
# 17           tobias harris        assists    over  equal
# 122          rachaad white       rush yds   under  equal
# 10            james harden        assists   under  equal
# 8             kyler murray       rush yds    over   edge
# 14            tyrese maxey       rebounds    over  equal
# 19             chris olave     receptions   under  equal
# 115    christian mccaffrey       rush yds   under   edge
# 95         taylor heinicke       rush yds    over  equal
# 98             aaron jones       rush yds   under   edge
# 26         deandre hopkins  receiving yds    over   edge
# 7             jrue holiday         points   under  equal
# 1    giannis antetokounmpo       rebounds    over  equal
# 0    giannis antetokounmpo         points    over  equal
# 5             jrue holiday       rebounds    over  equal
# 43          keith kirkwood  receiving yds   under   edge
# 103         terry mclaurin  receiving yds   under   edge
# 12            alvin kamara  receiving yds    over   edge
# 0              andy dalton       pass yds   under  equal
# 4              joel embiid         points   under  equal
# 136        jacoby brissett       rush yds    over  equal
# 6             jrue holiday        assists    over  equal
# 2              joel embiid        assists   under  equal
# 13            tyrese maxey         points    over  equal
# 16           tobias harris       rebounds    over  equal
# 145           amari cooper  receiving yds    over  equal
# 138        jacoby brissett       pass yds   under  equal
# 128         saquon barkley       rush yds    over  equal
# 134         christian kirk  receiving yds    over  equal
# 130         travis etienne       rush yds    over  equal
# 15           tobias harris         points    over  equal
# 125        trevor lawrence       pass yds    over   edge
# 157            davis mills       pass yds   under  equal
# 8             james harden         points    over  equal
# 141             nick chubb       rush yds   under   edge
# 121           chris godwin  receiving yds    over   edge
# 117             mike evans  receiving yds    over   edge
# 102           allen lazard  receiving yds   under   edge
# 50          marcus mariota       pass yds    over   edge
# 52          marcus mariota       rush yds    over  equal
# 53              joe burrow       pass yds    over   edge
# 97             aaron jones  receiving yds    over  equal
# 114      leonard fournette       rush yds    over  equal
# 159             derek carr       pass yds    over   edge
# 139          lamar jackson       pass yds    over   edge
# 12             brook lopez         points    over  equal
